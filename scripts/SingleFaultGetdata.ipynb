# %% [markdown]
# ## Process mutiple faults

# %%
import copy
import itertools
import json
import multiprocessing as mp
import operator
import os
import shutil
from collections import deque, namedtuple
from concurrent.futures import ProcessPoolExecutor, as_completed, wait
from copy import copy
from datetime import datetime

import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.pyplot as plt
import networkx as nx
import nlopt
import numpy as np
import pandas as pd
from matplotlib import gridspec
from obspy import read
from obspy.imaging.beachball import beach
from obspy.io.sac.util import SacIOError
from obspy.signal.cross_correlation import correlate, xcorr_max
from pyproj import Geod
from scipy.optimize import curve_fit, least_squares, minimize

from GetData import AbstractFaultProcess
from utils import *

def cc(fa, id1, t1, lat1, lon1, mag1, id2, t2, lat2, lon2, mag2):
    # cannot serialize pandas frame, which sliently quits multiprocessor
    print(f"Processing pair: {id1}-{id2}")

    outlierCC = fa.relocationConfig.get("outlierCC", 0.70)
    outlierDt = fa.relocationConfig.get("outlierDt", 35)
    numCCToFit = fa.relocationConfig.get("numCCToFit", 8)
    vgroup = fa.relocationConfig.get("vgroup", 3.75)
    outlierDx = vgroup * outlierDt
    geod = Geod(ellps="WGS84")

    def badCoverage(azi, maxgap=120.0):  # exclude those with azimuth gap larger than `maxgap`
        if len(azi) == 0:
            return False
        _azi = sorted([x % 360 for x in azi])
        diff = [_azi[i+1] - _azi[i] for i in range(len(_azi) - 1)]
        diff.append(360 - _azi[-1] + _azi[0])
        return np.any(np.array(diff) > maxgap)

    def residual_cosine(x, azi, dt):
        return x[0] + x[1] * np.cos(np.deg2rad(azi - x[2])) - dt

    def fit_cosine_ls_norm(azi, dx, cc, u0):
        mask = np.logical_and(cc >= outlierCC, np.abs(dx) <= outlierDx)
        _azi = azi[mask]
        _dx = dx[mask]
        if len(_azi) < numCCToFit or badCoverage(_azi):
            return np.array([np.nan, np.nan, np.nan]), np.array([np.inf, np.inf, np.inf])

        # initial solution affect the local minimum obtained
        res = least_squares(residual_cosine, [0., u0, 0.], args=(
            _azi, _dx), loss='soft_l1', jac='3-point')

        # On way of uncertainty, but inappropriate since we use other forms of norm
        # https://stackoverflow.com/a/21844726/8697614
        # J = res.jac
        # cov = np.linalg.inv(J.T.dot(J))
        # pcov = cov * (res.fun ** 2).sum() / (len(_azi) - len(res.x)) # reduced chi-square distribution
        # err = np.sqrt(np.diagonal(pcov))

        # Another way of uncertainty, still assume your function value is chi-square
        # https://stackoverflow.com/a/53489234/8697614, notice `dx[2] can exceed 360`
        # J = res.jac
        # cov = np.linalg.inv(J.T.dot(J))
        # err2 = np.sqrt(np.diagonal(cov) * np.abs(res.cost))
        # return res.x, err

        # The third way: bootstrap
        # This is what McGuire did, assuming 1s error in dt
        # err = bootstrap_uncertainty(_azi, _dx, [0., u0, 0.], stderr=1.0 * vgroup)
        # we instead use fitting residual as the error for bootstrap
        err = bootstrap_uncertainty(_azi, _dx, [0., u0, 0.], stderr=np.std(
            residual_cosine(res.x, _azi, _dx)))
        return res.x, err

    def bootstrap_uncertainty(x, y, p0, numiters=400, stderr=3.75, nsigma=1.0):
        x_cmt, x_dist, x_azi = [], [], []
        n = len(y)
        for i in range(numiters):
            yy = y + np.random.default_rng().normal(0.0, stderr, n)
            res = least_squares(residual_cosine, p0, args=(
                x, yy), loss='soft_l1', jac='3-point')
            x_cmt.append(res.x[0])
            x_dist.append(res.x[1])
            x_azi.append(res.x[2])
        return nsigma*np.std(x_cmt), nsigma*np.std(x_dist), nsigma*np.std(x_azi)

    fm1, fm2 = fa.fm[str(id1)]["np1"], fa.fm[str(id2)]["np1"]
    wv1, wv2 = [], []
    content = {x: [] for x in ["azi", "dt",
                               "cc", "net", "sta", "staLat", "staLon"]}
    nameBase = os.path.join(
        fa.ccDir, '-'.join(map(str, [id1, id2])))
    dfStations = pd.read_csv(os.path.join(fa.dir, "stations.csv"))
    for rs in dfStations.itertuples():
        waveName1 = str(id1) + '-' + rs.net + '-' + rs.sta + '.sac'
        waveName2 = str(id2) + '-' + rs.net + '-' + rs.sta + '.sac'
        wavePath1 = os.path.join(fa.waveDir, waveName1)
        wavePath2 = os.path.join(fa.waveDir, waveName2)

        if (
            np.isnan(rs.dist) or
            not os.path.isfile(wavePath1) or
            not os.path.isfile(wavePath2) or
            os.path.getsize(wavePath1) == 0 or
            os.path.getsize(wavePath2) == 0
        ):
            continue

        midLon, midLat = angularMean(
            [lon1, lon2]), angularMean([lat1, lat2])
        fz, _, _ = geod.inv(midLon, midLat, rs.lon,
                            rs.lat)  # fz: (-180, 180)
        try:
            st1 = read(wavePath1, format="SAC")
        except SacIOError:
            os.remove(wavePath1)
            continue
        try:
            st2 = read(wavePath2, format="SAC")
        except SacIOError:
            os.remove(wavePath2)
            continue

        if st1[0].stats["sampling_rate"] != st2[0].stats["sampling_rate"]:
            maxSamplingRate = max(st1[0].stats["sampling_rate"], st2[0].stats["sampling_rate"])
            for ss in [st1, st2]:
                if maxSamplingRate != ss[0].stats["sampling_rate"]:
                    ss.resample(maxSamplingRate, no_filter=True)

        cc = correlate(
            st1[0], st2[0], demean=True, normalize='naive',
            shift=min(st1[0].stats.npts, st2[0].stats.npts, int(
                np.round(outlierDt / st1[0].stats.delta * 2.0)))
        )
        # consider only positive cc
        shift, value = xcorr_max(cc, abs_max=False)
        dt = st1[0].stats.delta * shift
        content['azi'].append(fz)
        content['dt'].append(dt)
        content['cc'].append(value)
        content['net'].append(rs.net)
        content['sta'].append(rs.sta)
        content['staLat'].append(rs.lat)
        content['staLon'].append(rs.lon)
        wv1.append(st1[0].data)
        wv2.append(st2[0].data)

    pd.DataFrame(content).to_csv(nameBase + ".csv", index=False)
    if len(content["dt"]) < numCCToFit:
        return

    yy = np.array(content['dt']) * vgroup
    xx = np.array(content['azi'])
    # initial guess of distance, important for least square fit
    _, _, u0 = geod.inv(lon1, lat1, lon2, lat2)
    popt, pcov = fit_cosine_ls_norm(
        xx, yy, np.array(content['cc']), np.abs(u0 / 1e3))
    A, B, C = popt
    dA, dB, dC = pcov
    highcc = list(filter(lambda x: np.abs(x) >= outlierCC, content['cc']))
    summary = {
        'A': popt[0], 'B': popt[1], 'C': popt[2],
        'dA': pcov[0], 'dB': pcov[1], 'dC': pcov[2],
        'numHighCC': len(highcc),
    }
    with open(nameBase + ".json", "w") as fp:
        json.dump(summary, fp, indent=4)

    def plotCosineFit():
        fig = plt.figure(figsize=(8, 10))
        gs = gridspec.GridSpec(2, 2, width_ratios=[3, 1], height_ratios=[2, 1])
        ax0 = fig.add_subplot(gs[0, 0])
        ax1 = fig.add_subplot(gs[0, 1])
        ax2 = fig.add_subplot(
            gs[1, 0], projection=ccrs.AzimuthalEquidistant(lon1, lat1))
        ax2.stock_img()
        ax2.scatter(lon1, lat1, s=20, marker="*", c="orange",
                    transform=ccrs.PlateCarree(), zorder=2)

        ax3 = fig.add_axes([0.55, 0.89, 0.1, 0.1])
        ax3.set_aspect("equal")
        if np.isnan(fm1[0]):
            bc1 = beach([1.0, 1.0, 1.0, 0.0, 0.0, 0.0], facecolor="white",
                        edgecolor="lightgray", xy=(0.5, 0.75), width=0.4)
        else:
            bc1 = beach(fm1, facecolor="tab:blue", xy=(0.5, 0.75), width=0.4)
        if np.isnan(fm2[0]):
            bc2 = beach([1.0, 1.0, 1.0, 0.0, 0.0, 0.0], facecolor="white",
                        edgecolor="lightgray", xy=(0.5, 0.25), width=0.4)
        else:
            bc2 = beach(fm2, facecolor="tab:red", xy=(0.5, 0.25), width=0.4)
        ax3.add_collection(bc1)
        ax3.add_collection(bc2)
        ax3.axis('off')

        for i in range(len(wv1)):
            # do not set `step=delta` which may cause length mismatch
            y1 = np.arange(0.0, len(wv1[i])) * st1[0].stats.delta
            y2 = np.arange(0.0, len(wv2[i])) * st2[0].stats.delta
            w1 = wv1[i] - np.nanmean(wv1[i])
            w2 = wv2[i] - np.nanmean(wv2[i])
            w1 = w1 / np.nanmax(np.abs(w1)) * 8
            w2 = w2 / np.nanmax(np.abs(w2)) * 8

            isoutlier = not (np.abs(content["dt"][i]) <= outlierDt and np.abs(
                content["cc"][i]) >= outlierCC)
            linestyle = '--' if isoutlier else '-'
            alpha = 0.2 if isoutlier else 1.0
            fc = 'white' if isoutlier else 'tab:green'
            ax0.plot(y1, w1 + content["azi"][i], color="tab:blue",
                     linestyle=linestyle, alpha=alpha, clip_on=False)
            ax0.plot(y2, w2 + content["azi"][i], color="tab:red",
                     linestyle=linestyle, alpha=alpha, clip_on=False)
            ax1.scatter(content["dt"][i], content["azi"][i],
                        fc=fc, s=15, marker="o", ec="black", zorder=2)

            trajectorColor = "gray" if isoutlier else "tab:pink"
            trajectorStyle = "--" if isoutlier else "-"
            ax2.plot([lon1, content["staLon"][i]], [lat1, content["staLat"][i]],
                     color=trajectorColor, transform=ccrs.Geodetic(), zorder=1, linestyle=trajectorStyle)

        xx = np.arange(-180, 180, 1.0)
        if np.isnan(A):
            yy = np.array([np.nan for _ in xx])
            fittingColor = "gray"
        else:
            yy = A + B * np.cos(np.deg2rad(xx - C))
            yy /= vgroup
            fittingColor = "tab:orange"

        ax1.plot(yy, xx, c=fittingColor, zorder=1)
        _b, _c = B, C
        if _b < 0:
            _b *= -1
            _c += 180
        _c %= 360
        ax1.text(0.5, 1.05, "$\Delta x = \;$" + f"{_b:.0f}" + "$\;\pm \;$" + f"{dB:.0f}" + "$\;\mathrm{km}$",
                 ha='center', va='center', transform=ax1.transAxes, backgroundcolor="steelblue", color="white")
        ax1.text(0.5, 1.12, r"$\theta = \;$" + f"{_c:.1f}" + "$\;\pm \;$" + f"{dC:.1f}" + "$^{\circ}$",
                 ha='center', va='center', transform=ax1.transAxes, backgroundcolor="steelblue", color="white")
        ax0.set_ylim([-180, 180])
        ax1.set_ylim([-180, 180])
        ax1.set_xlim([-outlierDt, outlierDt])
        ax1.set_yticklabels([])
        ax1.grid(True, which="major", color='gray',
                 linestyle='--', linewidth=1)
        ax1.set_xlabel("$\Delta T$ (second)")
        ax0.set_xlabel("Time (second)")
        ax0.set_ylabel("Azimuth (deg)")
        ax0.autoscale(enable=True, axis='x', tight=True)

        l1, = ax0.plot([], [], color="tab:blue")
        l2, = ax0.plot([], [], color="tab:red")
        _tstr1 = datetime.fromisoformat(t1)
        _tstr1 = _tstr1.strftime("%Y-%m-%d %H:%M:%S"+f'  M{mag1:.1f}')
        _tstr2 = datetime.fromisoformat(t2)
        _tstr2 = _tstr2.strftime("%Y-%m-%d %H:%M:%S"+f'  M{mag2:.1f}')
        ax0.legend([l1, l2], [_tstr1, _tstr2],
                   loc="upper center", bbox_to_anchor=(0.5, 1.18))

        l1, = ax1.plot([], [], color="tab:orange")
        l2 = ax0.scatter([], [], fc='tab:green', s=15, marker="o", ec="black")
        l3 = ax0.scatter([], [], fc='white', s=15, marker="o", ec="black")
        ax1.legend([l1, l2, l3], ["Cosine Fitting", "Observation (cc $\geq \;$" +
                                  f"{outlierCC:.2f})", f"Observation (cc $<$ {outlierCC:.2f})"], loc="lower center", bbox_to_anchor=(0.5, -0.3))

        l1, = ax2.plot([], [], color="tab:pink", linestyle="-")
        l2, = ax2.plot([], [], color="gray", linestyle="--")
        l3 = ax2.scatter([], [], s=20, marker="*", c="orange")
        ax2.legend([l1, l2, l3], ["$\mathrm{cc} \geq \;$"+f"{outlierCC:.2f}", "$\mathrm{cc} <\;$" +
                                  f"{outlierCC:.2f}", fa.name], loc="lower left", bbox_to_anchor=(-0.60, 0.0))
        fig.savefig(nameBase + ".pdf")
        print(f"Saved {os.path.basename(nameBase)}.")
        plt.close(fig)

    plotCosineFit()


def crossCorrelate(fa):
    dfPairss = pd.read_csv(os.path.join(fa.dir, "catalog-pair.csv"))
    futures = []

    ccFiles = [os.path.join(fa.ccDir, x) for x in os.listdir(fa.ccDir)]
    for f in ccFiles:
        os.remove(f)
    # for r in dfPairss.itertuples(index=True):
    #     print(f"{r.Index + 1}/{dfPairss.shape[0]} ...")
    #     cc(fa, r.id1, r.t1, r.lat1, r.lon1, r.mag1, r.id2, r.t2, r.lat2, r.lon2, r.mag2)
    with ProcessPoolExecutor(max_workers=20) as executor:
        for r in dfPairss.itertuples(index=True):
            futures.append(executor.submit(cc, fa, r.id1, r.t1, r.lat1,
                                           r.lon1, r.mag1, r.id2, r.t2, r.lat2, r.lon2, r.mag2))
        [future.result() for future in as_completed(futures)]


class RelocationProcedure(AbstractFaultProcess):

    def __init__(self, name, *args, **kwargs):
        super().__init__(name)
        self.waveDir = os.path.join(self.dir, "waves")
        if not os.path.isdir(self.waveDir):
            os.mkdir(self.waveDir)
        self.ccDir = os.path.join(self.dir, "cc")
        if not os.path.isdir(self.ccDir):
            os.mkdir(self.ccDir)
        with open(os.path.join(self.dir, "mt.json")) as fp:
            self.fm = json.load(fp)
        self.relocationConfig = kwargs


def optimize(fa):

    def formEdge(x: dict, linkNum: int = 8):
        return \
            (not np.isnan(x['B'])) and \
            (not np.isinf(x['dB'])) and \
            x['numHighCC'] >= linkNum

    def buildPairGraph():
        dfPairs = pd.read_csv(os.path.join(fa.dir, "catalog-pair.csv"))
        files = (x for x in os.listdir(fa.ccDir) if x.endswith(".json"))
        pairkey2row = {(r.id1, r.id2): r for r in dfPairs.itertuples()}

        G = nx.Graph()
        for file in files:
            with open(os.path.join(fa.ccDir, file), "r") as fp:
                data = json.load(fp)
                if formEdge(data):
                    info = os.path.splitext(file)[0].split('-')
                    id1, id2 = map(str, info)
                    r = pairkey2row.get((id1, id2), None)
                    if not r:
                        continue
                    if id1 != r.id1 or id2 != r.id2:
                        raise ValueError("pair id mismatch.")

                    # duplicate hashing is ignored
                    G.add_node(id1,
                               lat=r.lat1, lon=r.lon1, mag=r.mag1,
                               t=r.t1, group=-1)
                    G.add_node(id2,
                               lat=r.lat2, lon=r.lon2, mag=r.mag2,
                               t=r.t2, group=-1)
                    G.add_edge(id1, id2,
                               B=data['B'], C=data['C'],
                               dB=data['dB'], dC=data['dC'])
        return G

    def traverseGraph(G, relocateOneWay=True):
        # BFS, relocate one group of events by single reference abiding shortest path
        # This, however, does not account for discrepancy with direct observation and
        # new locations. Using optimization is perferred, see below.

        # If not relocate, it aims to idenfity groups and label accordingly.
        def traverse(n):
            queueSet.add(n)
            for k in G.adj[n].keys():
                if (not visited[k]) and (k not in queueSet):
                    if relocateOneWay:
                        B, C = G.adj[n][k]['B'], G.adj[n][k]['C']
                        # all pairs id1 is more recent than id2
                        C = C if IDTimePair[n] > IDTimePair[k] else C + 180.0  # only change `B` or `C`, not both
                        lat1, lon1 = G.nodes.data(
                            'lat')[n], G.nodes.data('lon')[n]
                        lon2, lat2, _ = geod.fwd(lon1, lat1, C, B*1e3)
                        G.nodes[k].update(lat=lat2, lon=lon2)
                    visited[k] = True
                    IDTimePairDynamic.pop(k, None)
                    G.nodes[k].update(group=groupid)
                    Q.append(k)
                    queueSet.add(k)

        geod = Geod(ellps="WGS84")
        Q = deque()
        queueSet = set()
        visited = dict(G.nodes.data('visited'))
        IDTimePair = dict(G.nodes.data("t"))
        IDTimePairDynamic = dict(G.nodes.data("t"))
        groupid = 1

        while count := sum([1 for (k, v) in visited.items() if not v]) > 0:
            # use newest event as reference
            startID = max(IDTimePairDynamic, key=IDTimePairDynamic.get)
            Q.append(startID)
            visited[startID] = True
            IDTimePairDynamic.pop(startID)
            G.nodes[startID].update(group=groupid)
            while Q:
                traverse(Q.popleft())
            groupid += 1
        return G

    def traverseOptimizeGraph(G):
        Q = deque()
        geod = Geod(ellps="WGS84")
        optimized = dict(G.nodes.data('visited'))
        queueSet = set()
        IDTimePair = dict(G.nodes.data("t"))
        IDTimePair2 = dict(G.nodes.data("t"))

        def optimizeNodeLocation(node):

            def objective(x, lons, lats, B, C, dB, dC):
                res = 0.0
                for i in range(len(lons)):
                    fz, _, dist = geod.inv(x[0], x[1], lons[i], lats[i])
                    fz, dist = _normalize_fz_dist(fz, dist)
                    res += np.abs(angularDiff(fz, C[i]) / dC[i]) + \
                        np.abs((dist/1e3 - B[i]) / dB[i])
                return res

            ks = G.adj[node].keys()
            queueSet.add(node)
            IDTimePair.pop(node, None)
            for k in ks:
                if (not optimized[k]) and (k not in queueSet):
                    Q.append(k)
                    queueSet.add(k)
                    IDTimePair.pop(k, None)

            lons = np.array([G.nodes.data('lon')[k] for k in ks])
            lats = np.array([G.nodes.data('lat')[k] for k in ks])
            x0 = np.array([angularMean(lons), angularMean(lats)])
            Bs = np.array([G.adj[node][k]['B'] for k in ks])
            Cs = np.array([G.adj[node][k]['C'] for k in ks])
            dBs = np.array([G.adj[node][k]['dB'] for k in ks])
            dCs = np.array([G.adj[node][k]['dC'] for k in ks])
            for i, k in enumerate(ks):
                # all pairs id1 is more recent than id2
                if IDTimePair2[node] < IDTimePair2[k]:  # correction for direction
                    Cs[i] += 180.0
                if Bs[i] < 0:  # correction for negative distance
                    Bs[i] *= -1
                    Cs[i] += 180.0
                Cs[i] %= 360  # correction for azimuth angle between [0, 360)
            res = minimize(objective, x0, args=(
                lons, lats, Bs, Cs, dBs, dCs), method="Nelder-Mead")
            G.nodes[node].update(lat=res.x[1], lon=res.x[0])
            optimized[node] = True

        while count := sum([1 for (k, v) in optimized.items() if not v]) > 0:
            # startID = min([k for (k, v) in optimized.items() if not v])
            startID = max(IDTimePair, key=IDTimePair.get)
            Q.append(startID)
            IDTimePair.pop(startID)
            while Q:
                optimizeNodeLocation(Q.popleft())
        return G

    def optimizeLocation(G, relocateTwoWay=True, relocateTwoWayIter=5, relocateGlobal=True):
        if relocateTwoWay:
            for _ in range(relocateTwoWayIter):
                traverseOptimizeGraph(G)

        data = {k: G.nodes[k] for k in G.nodes}
        uniqueGroupID = set([data[k]['group'] for k in data.keys()])
        linkContent = {x: [] for x in [
            "id1", "t1", "lat1", "lon1", "mag1",
            "id2", "t2", "lat2", "lon2", "mag2",
            "dist", "B", "dB",
            "azi", "C", "dC",
            "group", "weight",
        ]}
        geod = Geod(ellps="WGS84")
        IDTimePair = dict(G.nodes.data("t"))

        for gid in uniqueGroupID:
            es = [x for x in G.edges if data[x[0]]['group'] == gid]
            es.sort(key=lambda x: (IDTimePair[x[0]], IDTimePair[x[1]]), reverse=True)
            pks = list(set(itertools.chain(*es)))
            pks.sort(key=lambda x: IDTimePair[x], reverse=True)
            id2t = {k: IDTimePair[k] for k in pks}
            masterId = max(id2t, key=id2t.get)
            masterLat, masterLon = data[masterId]['lat'], data[masterId]['lon']
            key2id = {pks[i]: i for i in range(len(pks))}
            Bs = [G.edges[x]['B'] for x in es]
            Cs = [G.edges[x]['C'] for x in es]
            dBs = [G.edges[x]['dB'] for x in es]
            dCs = [G.edges[x]['dC'] for x in es]
            lat0 = np.array([data[x]['lat'] for x in pks])
            lon0 = np.array([data[x]['lon'] for x in pks])
            u0 = [[lat0[i], lon0[i]] for i in range(len(pks))]
            u0 = list(itertools.chain(*u0))
            u0.append(1)  # initial weight

            if not relocateGlobal:
                x = u0
            else:
                avglat0, avglon0 = angularMean(lat0), angularMean(lon0)
                searchRange = 10.0  # within 10 degree, should be sufficient
                # not rigorously right,
                # but we don't have events at polar region or date changing line
                lblat = np.clip(lat0 - searchRange, -90, 90)
                ublat = np.clip(lat0 + searchRange, -90, 90)
                lblon = np.clip(lon0 - searchRange, -180, 180)
                ublon = np.clip(lon0 + searchRange, -180, 180)

                lb = [[x, y] for x, y in zip(lblat, lblon)]
                lb = list(itertools.chain(*lb))
                lb.append(0.2)  # lower bound for relative weight
                ub = [[x, y] for x, y in zip(ublat, ublon)]
                ub = list(itertools.chain(*ub))
                ub.append(2)  # upper bound for relative weight

                objective, masterLatitudeConstraint, masterLongitudeConstraint = \
                    objectiveFuncFactory(
                        masterId, masterLat, masterLon, Bs, Cs, dBs, dCs, key2id, es)

                opt = nlopt.opt(nlopt.LN_COBYLA, 2*len(pks)+1)
                opt.set_min_objective(objective)
                opt.add_equality_constraint(masterLatitudeConstraint, 1e-6)
                opt.add_equality_constraint(masterLongitudeConstraint, 1e-6)
                opt.set_lower_bounds(lb)
                opt.set_upper_bounds(ub)
                opt.set_xtol_rel(1e-6)
                x = opt.optimize(u0)

            for e in es:
                _add_link_content(linkContent, G, e, x, key2id, geod, IDTimePair)

        pd.DataFrame(linkContent).to_csv(os.path.join(
            fa.dir, "catalog-link.csv"), index=False)
        content = {'id': [], 'time': [], 'lat': [],
                   'lon': [], 'mag': [], 'group': []}
        content['id'].extend(linkContent['id1'])
        content['id'].extend(linkContent['id2'])
        content['time'].extend(linkContent['t1'])
        content['time'].extend(linkContent['t2'])
        content['lat'].extend(linkContent['lat1'])
        content['lat'].extend(linkContent['lat2'])
        content['lon'].extend(linkContent['lon1'])
        content['lon'].extend(linkContent['lon2'])
        content['mag'].extend(linkContent['mag1'])
        content['mag'].extend(linkContent['mag2'])
        content['group'].extend(linkContent['group'])
        content['group'].extend(linkContent['group'])
        pd.DataFrame(content).drop_duplicates(subset=['id'], keep='last').sort_values(
            by="time").to_csv(os.path.join(fa.dir, "catalog-relocated.csv"), index=False)

    def _add_link_content(linkContent, G, e, sol, key2id, geod, IDTimePair):
        # repeated code
        # all pairs id1 is more recent than id2
        if IDTimePair[e[0]] < IDTimePair[e[1]]:
            e = (e[1], e[0])
        id1, id2 = key2id[e[0]], key2id[e[1]]

        lat1, lon1 = sol[2*id1], sol[2*id1+1]
        lat2, lon2 = sol[2*id2], sol[2*id2+1]

        linkContent['id1'].append(e[0])
        linkContent['t1'].append(G.nodes[e[0]]['t'])
        linkContent['lat1'].append(lat1)
        linkContent['lon1'].append(lon1)
        linkContent['mag1'].append(G.nodes[e[0]]['mag'])
        linkContent['id2'].append(e[1])
        linkContent['t2'].append(G.nodes[e[1]]['t'])
        linkContent['lat2'].append(lat2)
        linkContent['lon2'].append(lon2)
        linkContent['mag2'].append(G.nodes[e[1]]['mag'])
        fz, dist = _objection_val(sol, e, key2id, geod)
        linkContent['dist'].append(dist/1e3)
        linkContent['azi'].append(fz)
        bb, cc = G.edges[e]['B'], G.edges[e]['C'] % 360
        cc, bb = _normalize_fz_dist(cc, bb)
        linkContent['B'].append(bb)
        linkContent['C'].append(cc)
        linkContent['dB'].append(G.edges[e]['dB'])
        linkContent['dC'].append(G.edges[e]['dC'] % 360)
        linkContent['group'].append(G.nodes[e[0]]['group'])
        linkContent['weight'].append(sol[-1])

    def mergeCatalogue():
        content_strs = ['id', 'time', 'lat', 'lon', 'mag', 'group']
        content = {x: [] for x in content_strs}
        dforg = pd.read_csv(os.path.join(fa.dir, "catalog.csv"))
        dfcc = pd.read_csv(os.path.join(fa.dir, "catalog-relocated.csv"))
        relocatedID = set(dfcc["id"].to_list())
        for r in dfcc.itertuples():
            content['id'].append(r.id)
            content['time'].append(r.time)
            content['lat'].append(r.lat)
            content['lon'].append(r.lon)
            content['mag'].append(r.mag)
            content['group'].append(r.group)
        for r in dforg.itertuples():
            if r.id not in relocatedID:
                mw = mag2mw(r.mag, r.magType)
                content['id'].append(r.id)
                content['time'].append(r.time)
                content['lat'].append(r.lat)
                content['lon'].append(r.lon)
                content['mag'].append(mw)
                content['group'].append(-1)
        pd.DataFrame(content).sort_values(by=["time"]).to_csv(
            os.path.join(fa.dir, "catalog-merged.csv"), index=False)

    def _objection_val(sol, e: list, key2id: dict, geod):
        id1, id2 = key2id[e[0]], key2id[e[1]]
        lat1, lon1 = sol[2*id1], sol[2*id1+1]
        lat2, lon2 = sol[2*id2], sol[2*id2+1]
        fz, _, dist = geod.inv(lon1, lat1, lon2, lat2)
        fz, dist = _normalize_fz_dist(fz, dist)
        return fz, dist

    def _normalize_fz_dist(fz: float, dist: float):
        if dist < 0:
            dist *= -1
            fz += 180.0
        fz %= 360
        return fz, dist

    def objectiveFuncFactory(masterID, masterLat, masterLon, Bs, Cs, dBs, dCs, key2id, es, weight=1.0):
        # weight denotes relative contribution between `dist` and `azi`
        geod = Geod(ellps="WGS84")
        _B = copy.copy(Bs)
        _C = list(map(lambda x: x % 360, Cs))
        _dB = copy.copy(dBs)
        _dC = list(map(lambda x: x % 360, dCs))
        for i in range(len(_B)):
            _C[i], _B[i] = _normalize_fz_dist(_C[i], _B[i])
            _dC[i], _dB[i] = _normalize_fz_dist(_dC[i], _dB[i])
            if _dC[i] > 180:
                _dC[i] = 360.0 - _dC[i]

        _dB2 = [x**2 for x in _dB]
        _dC2 = [x**2 for x in _dC]

        def objective(x, grad):
            # x = [lat_1, lon_1, lat_2, lon_2, ..., lat_n, lon_n, weight]
            if grad.size > 0:
                raise RuntimeError("Use gradient free method!")

            y = 0.0
            for i, e in enumerate(es):
                fz, dist = _objection_val(x, e, key2id, geod)
                y += np.abs((dist/1e3 - _B[i]) / _dB[i]) + \
                    x[-1] * np.abs(angularDiff(fz, _C[i]) / _dC[i])
            return np.sqrt(y)

        def masterLatitudeConstraint(x, grad):
            if grad.size > 0:
                raise RuntimeError("Use gradient free method!")
            return x[2 * key2id[masterID]] - masterLat

        def masterLongitudeConstraint(x, grad):
            if grad.size > 0:
                raise RuntimeError("User gradient free method!")
            return x[2 * key2id[masterID] + 1] - masterLon

        return objective, masterLatitudeConstraint, masterLongitudeConstraint

    G = buildPairGraph()
    G = traverseGraph(G, True)
    optimizeLocation(G, relocateTwoWay=True, relocateGlobal=False)
    mergeCatalogue()

if __name__ == "__main__":

    names = dfFaults["Name"].to_list()
    for name in names:
        print(name)
        f = RelocationProcedure(name.strip())
        crossCorrelate(f)
        optimize(f)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 13
#      10 from copy import copy
#      11 from datetime import datetime
# ---> 13 import cartopy.crs as ccrs
#      14 import cartopy.feature as cfeature
#      15 import matplotlib.pyplot as plt
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\cartopy\__init__.py:106
#     102     pass
#     104 # Commonly used sub-modules. Imported here to provide end-user
#     105 # convenience.
# --> 106 import cartopy.crs  # noqa: E402  module-level imports
#     107 import cartopy.feature  # noqa: E402,F401  (unused import)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\cartopy\crs.py:20
#      17 import math
#      18 import warnings
# ---> 20 import numpy as np
#      21 from pyproj import Transformer
#      22 from pyproj.exceptions import ProjError
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\__init__.py:127
#     124 from . import _distributor_init
#     126 try:
# --> 127     from numpy.__config__ import show_config
#     128 except ImportError as e:
#     129     msg = """Error importing numpy: you should not try to import numpy from
#     130     its source directory; please exit the numpy source tree, and relaunch
#     131     your python interpreter from there."""
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\__config__.py:4
#       1 # This file is generated by numpy's build process
#       2 # It contains system_info results at the time of building this package.
#       3 from enum import Enum
# ----> 4 from numpy._core._multiarray_umath import (
#       5     __cpu_features__,
#       6     __cpu_baseline__,
#       7     __cpu_dispatch__,
#       8 )
#      10 __all__ = ["show_config"]
#      11 _built_with_meson = True
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\_core\__init__.py:74
#      72 from .numerictypes import sctypes, sctypeDict
#      73 multiarray.set_typeDict(nt.sctypeDict)
# ---> 74 from . import numeric
#      75 from .numeric import *
#      76 from . import fromnumeric
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\_core\numeric.py:2704
#    2702 from . import arrayprint
#    2703 from .arrayprint import *
# -> 2704 from . import _asarray
#    2705 from ._asarray import *
#    2706 from . import _ufunc_config
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1147, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:936, in exec_module(self, module)
#
# File <frozen importlib._bootstrap_external>:1032, in get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:1130, in get_data(self, path)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Process one single Fault

# %%
from obspy import UTCDateTime
from obspy.clients.fdsn import Client
from urllib.parse import urlparse, parse_qs
import pandas as pd
import os
import json
from concurrent.futures import ThreadPoolExecutor, as_completed

waveDir = r"C:\Users\student\Downloads\OTF2021-1.0.1\cross-correl-sample\six_earthquakes\Fault1"

def getCatalog(minMag=3.0, extent=0.5,
                   startTime=UTCDateTime("2020-09-06T6:00:00"),
                   endTime=UTCDateTime("2020-09-10T23:00:00"),
                   suffix="",
                   mt=True):

    # Define the geographic coordinates for your request
    latitude = 7.7
    longitude = -36
    minradius = 0.0  # Minimum distance from the event in degrees
    maxradius = 10.0  # Maximum distance from the event in degrees

    try:
        client = Client("USGS")
        cat = client.get_events(starttime=startTime, endtime=endTime,
                                latitude=latitude, longitude=longitude,
                                minradius=minradius, maxradius=maxradius,
                                minmagnitude=minMag,
                                orderby="time")
    except Exception as e:
        print(f"Error retrieving catalog: {str(e)}")
        cat = []

    content = {
        "time": [],
        "mag": [],
        "magType": [],
        "lat": [],
        "lon": [],
        "dep": [],
        "text": [],
        "id": []
    }

    for event in cat:
        content["time"].append(str(event.origins[0].time.datetime))
        content["mag"].append(event.magnitudes[0].mag)
        content["magType"].append(event.magnitudes[0].magnitude_type)
        content["lat"].append(event.origins[0].latitude)
        content["lon"].append(event.origins[0].longitude)
        content["dep"].append(event.origins[0].depth)
        content["text"].append(event.event_descriptions[0].text if event.event_descriptions else "")
        content["id"].append(parse_qs(urlparse(event.resource_id.id).query)["eventid"][0])

        
     # Check if all arrays have the same length
    array_lengths = [len(arr) for arr in content.values()]
    if len(set(array_lengths)) > 1:
        print(f"Array lengths: {array_lengths}")
        raise ValueError("All arrays must be of the same length")

    df = pd.DataFrame(content)
    df.to_csv(os.path.join(waveDir, f"catalog{suffix}.csv"), index=False)

    if mt:
        mt = {}
        with ThreadPoolExecutor(max_workers=6) as executor:
            futures = {executor.submit(getMomentTensorByEventID, client, eid): eid for eid in content["id"]}
            for future in as_completed(futures):
                eid = futures[future]
                try:
                    data = future.result()
                    mt[eid] = {"np1": data[0], "np2": data[1], "mt": data[2]}
                except Exception as e:
                    print(f"Error retrieving moment tensor for event {eid}: {str(e)}")
                    mt[eid] = {"np1": [float("NaN")] * 3, "np2": [float("NaN")] * 3, "mt": [float("NaN")] * 6}
        
        with open(os.path.join(waveDir, "mt.json"), "w") as fp:
            json.dump(mt, fp, indent=4)


def getMomentTensorByEventID(client, eid):
    e = client.get_events(eventid=eid)
    fm = e[0].focal_mechanisms
    if not fm:
        return [float("NaN")] * 3, [float("NaN")] * 3, [float("NaN")] * 6
    for _fm in reversed(fm):
        if _fm.nodal_planes or _fm.moment_tensor.tensor:
            preferred_fm = _fm
            break
    ts = preferred_fm.moment_tensor.tensor if preferred_fm.moment_tensor else None
    npp = preferred_fm.nodal_planes if preferred_fm.nodal_planes else None
    mt = [ts.m_rr, ts.m_tt, ts.m_pp, ts.m_rt, ts.m_rp, ts.m_tp] if ts else [float("NaN")] * 6
    np1 = [npp.nodal_plane_1.strike, npp.nodal_plane_1.dip, npp.nodal_plane_1.rake] if npp else [float("NaN")] * 3
    np2 = [npp.nodal_plane_2.strike, npp.nodal_plane_2.dip, npp.nodal_plane_2.rake] if npp else [float("NaN")] * 3
    return np1, np2, mt
getCatalog()

# %%
#Get moment tensor for fake eventID
from obspy import UTCDateTime
from obspy.clients.fdsn import Client
from urllib.parse import urlparse, parse_qs
import pandas as pd
import os
import json
from concurrent.futures import ThreadPoolExecutor, as_completed

waveDir = r"C:\Users\student\Downloads\OTF2021-1.0.1\cross-correl-sample\six_earthquakes\Fault1"

def getCatalog():

    df = pd.read_csv(os.path.join(waveDir, "catalog.csv"))    
    client = Client("USGS")
    
    mt = {}
   
    with ThreadPoolExecutor(max_workers=6) as executor:
        futures = {executor.submit(getMomentTensorByEventID, client, eid): eid for eid in df["id"]}
        for future in as_completed(futures):
            eid = futures[future]
            try:
                data = future.result()
                mt[eid] = {"np1": data[0], "np2": data[1], "mt": data[2]}
            except Exception as e:
                print(f"Error retrieving moment tensor for event {eid}: {str(e)}")
                mt[eid] = {"np1": [float("NaN")] * 3, "np2": [float("NaN")] * 3, "mt": [float("NaN")] * 6}
        
    with open(os.path.join(waveDir, "mt.json"), "w") as fp:
        json.dump(mt, fp, indent=4)


def getMomentTensorByEventID(client, eid):
    e = client.get_events(eventid=eid)
    fm = e[0].focal_mechanisms
    if not fm:
        return [float("NaN")] * 3, [float("NaN")] * 3, [float("NaN")] * 6
    for _fm in reversed(fm):
        if _fm.nodal_planes or _fm.moment_tensor.tensor:
            preferred_fm = _fm
            break
    ts = preferred_fm.moment_tensor.tensor if preferred_fm.moment_tensor else None
    npp = preferred_fm.nodal_planes if preferred_fm.nodal_planes else None
    mt = [ts.m_rr, ts.m_tt, ts.m_pp, ts.m_rt, ts.m_rp, ts.m_tp] if ts else [float("NaN")] * 6
    np1 = [npp.nodal_plane_1.strike, npp.nodal_plane_1.dip, npp.nodal_plane_1.rake] if npp else [float("NaN")] * 3
    np2 = [npp.nodal_plane_2.strike, npp.nodal_plane_2.dip, npp.nodal_plane_2.rake] if npp else [float("NaN")] * 3
    return np1, np2, mt

getCatalog()

# %%
def getCandidateStations(minDist=1000.0, ddeg=10.0, nnearest=1, plot=True):
        dfStations_ = dfStations
        NET = dfStations_['#Network '].to_list()
        STA = dfStations_[' Station '].to_list()
        LAT = dfStations_[' Latitude '].to_list()
        LON = dfStations_[' Longitude '].to_list()
        DEP = dfStations_[' Elevation '].to_list()

        degs = np.arange(0.0, 359.0, step=ddeg)
        sep = [(degs[x], degs[x+1]) for x in range(len(degs)-1)]
        sep.append((degs[-1], 360.0))

        geod = Geod(ellps="WGS84")
        staType = namedtuple(
            'station', ['net', 'sta', 'lat', 'lon', 'dep', 'azi', 'dist'])
        stas = [[] for _ in range(len(sep))]
        lon, lat = -36, 7.7
        pools = {}
        for i in range(len(STA)):
            fz, _, d = geod.inv(lon, lat, LON[i], LAT[i])
            if fz < 0:
                fz += 360
            d /= 1e3
            if d < minDist:
                continue
            id = int(np.floor(fz / ddeg))
            target = staType(NET[i], STA[i], LAT[i], LON[i], DEP[i], fz, d)
            stas[id].append(target)
            pools[f"{NET[i]}-{STA[i]}"] = target

        stass = []
        for sta in stas:
            heapq.heapify(sta)
            selected = heapq.nsmallest(nnearest, sta, key=lambda x: x.dist)
            stass.extend(selected)
            [pools.pop(f"{x.net}-{x.sta}") for x in selected]

        content = {
            'net': [x.net for x in stass],
            'sta': [x.sta for x in stass],
            'lat': [x.lat for x in stass],
            'lon': [x.lon for x in stass],
            'dep': [x.dep for x in stass],
            'azi': [x.azi for x in stass],
            'dist': [x.dist for x in stass],
        }
        pd.DataFrame(content).to_csv(os.path.join(
            waveDir, "stations.csv"), index=False)

        if not plot:
            return

        fig = plt.figure(figsize=(10, 6))
        ax = fig.add_subplot(1, 1, 1, projection=ccrs.Robinson(lon))
        ax.stock_img()
        ax.coastlines()
        for i in range(len(content['sta'])):
            ax.plot([content['lon'][i], lon], [content['lat'][i], lat],
                    transform=ccrs.Geodetic(), linestyle=':', color="tab:red", zorder=1)
        ax.scatter(lon, lat, s=20, marker="*", c="orange",
                   transform=ccrs.PlateCarree(), zorder=2)
        ax.scatter(content['lon'], content['lat'], s=10, marker='s',
                   c='tab:purple', transform=ccrs.PlateCarree(), zorder=2)
        ax.set_title("Mid-Atlantic Ridge")
        fig.savefig(os.path.join(waveDir, "stations.pdf"))
        plt.close(fig)
getCandidateStations()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\Users\student\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File d:\Users\student\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File d:\Users\student\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '#Network '
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[123], line 67
#      65         fig.savefig(os.path.join(waveDir, "stations.pdf"))
#      66         plt.close(fig)
# ---> 67 getCandidateStations()
#
# Cell In[123], line 3, in getCandidateStations(minDist, ddeg, nnearest, plot)
#       1 def getCandidateStations(minDist=1000.0, ddeg=10.0, nnearest=1, plot=True):
#       2         dfStations_ = dfStations
# ----> 3         NET = dfStations_['#Network '].to_list()
#       4         STA = dfStations_[' Station '].to_list()
#       5         LAT = dfStations_[' Latitude '].to_list()
#
# File d:\Users\student\anaconda3\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File d:\Users\student\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: '#Network '

# %%
waveDir = r"C:\Users\student\Downloads\OTF2021-1.0.1\cross-correl-sample\six_earthquakes\Fault1"
def getCandidateEvents(
                           timeFunc=lambda t: t >= datetime.datetime(
                               1990, 1, 1),
                           magFunc=lambda m1, m2, dm: m1 >= (m2 - dm)
                           ):
        df = pd.read_csv(os.path.join(waveDir, "catalog.csv"))
        refLat, refLon =  7.7, -36
        magCutOff = 1.0
        p0 = geopy.Point(refLat, refLon)
        content = {x: [] for x in [
            "id", "time", "lat", "lon", "mag", "along_strike_distance"
        ]}
        for r in df.itertuples(index=True):
            mw = mag2mw(r.mag, r.magType)
            if (
                timeFunc(datetime.datetime.fromisoformat(r.time)) and
                magFunc(mw, magCutOff, dm=0)
            ):
                content['id'].append(r.id)
                content['time'].append(r.time)
                content['lat'].append(r.lat)
                content['lon'].append(r.lon)
                content['mag'].append(mw)
                content['along_strike_distance'].append(
                    distance.distance(p0, geopy.Point(r.lat, r.lon)).km)
        pd.DataFrame(content).to_csv(os.path.join(
            waveDir, "catalog-candidate.csv"), index=False)
getCandidateEvents()

# %%
def isPair(d1, m1, d2, m2, dc=125.0, mc=0.41, LARGE_MAG_PAIR=5.99):
    # Notice, for instance, 5.4 - 5.2 > 0.2 is True
    return np.abs(d1 - d2) <= dc and (
        np.abs(m1 - m2) <= mc or (m1 >= LARGE_MAG_PAIR and m2 >= LARGE_MAG_PAIR)
    )

def getEventPairs(*args, **kwargs):
    # Denormalized table
    content = {
        "id1": [],
        "t1": [],
        "lat1": [],
        "lon1": [],
        "mag1": [],
        "dist1": [],
        "id2": [],
        "t2": [],
        "lat2": [],
        "lon2": [],
        "mag2": [],
        "dist2": [],
        "dmag": [],
        "ddist": [],
    }
    df = pd.read_csv(os.path.join(waveDir, "catalog-candidate.csv"))
    numrec = len(df.index)
    for i in range(numrec):
        r1 = df.loc[i]
        for j in range(i + 1, numrec):
            r2 = df.loc[j]
            if isPair(
                r1.along_strike_distance,
                r1.mag,
                r2.along_strike_distance,
                r2.mag,
                *args,
                **kwargs,
            ):
                content["id1"].append(r1.id)
                content["t1"].append(r1.time)
                content["lat1"].append(r1.lat)
                content["lon1"].append(r1.lon)
                content["mag1"].append(r1.mag)
                content["dist1"].append(r1.along_strike_distance)
                content["id2"].append(r2.id)
                content["t2"].append(r2.time)
                content["lat2"].append(r2.lat)
                content["lon2"].append(r2.lon)
                content["mag2"].append(r2.mag)
                content["dist2"].append(r2.along_strike_distance)
                content["dmag"].append(np.abs(r1.mag - r2.mag))
                content["ddist"].append(
                    np.abs(r1.along_strike_distance - r2.along_strike_distance)
                )
    pd.DataFrame(content).to_csv(
        os.path.join(waveDir, "catalog-pair.csv"), index=False
    )

getEventPairs()

# %%
def getWaveform(waveClient="IRIS",
                groupVelocityWindow=[5.0, 3.0],  # km/s
                filterHzWindow=[0.02, 0.04],
                channel="BHZ"):
    clientIRIS = Client(waveClient, timeout=30)
    waveDir = r"C:\Users\student\Downloads\OTF2021-1.0.1\cross-correl-sample\six_earthquakes\Fault1"
    dfPairs = pd.read_csv(os.path.join(waveDir, "catalog-pair.csv"))
    dfStations = pd.read_csv(os.path.join(waveDir, "stations.csv"))
    waveDir = os.path.join(waveDir, "waves")
    if not os.path.isdir(waveDir):
        os.mkdir(waveDir)

    def getWaveFormByVelocityWindow(tstr: str, net: str, sta: str, dist: float):
        dt1, dt2 = dist / groupVelocityWindow[0], dist / groupVelocityWindow[1]  # seconds
        t0 = UTCDateTime(tstr)
        st = clientIRIS.get_waveforms(
            net, sta, "*", channel, t0 + dt1, t0 + dt2, attach_response=True)
        try:
            st.remove_response()
        except:
            pass  # then no instrument removal performed
        finally:
            return st

    def getAndSave(eid, tstr, net, sta, dist):
        waveFileName = str(eid) + '-' + net + '-' + sta + '.sac'
        waveFilePath = os.path.join(waveDir, waveFileName)
        if os.path.isfile(waveFilePath) and os.path.getsize(waveFilePath) > 0:
            return
        try:
            with open(waveFilePath, "w"):
                pass
            st = getWaveFormByVelocityWindow(tstr, net, sta, dist)
        except FDSNNoDataException:
            pass
        except Exception as e:
            pass
        else:
            if st and st.count != 0:
                st.detrend(type="constant")
                st.filter(
                    type="bandpass", freqmin=filterHzWindow[0], freqmax=filterHzWindow[1], zerophase=True)
                print(f"Saving {waveFileName}")
                st[0].write(waveFilePath, format="SAC")
        finally:
            if os.path.isfile(waveFilePath) and os.path.getsize(waveFilePath) == 0:
                os.remove(waveFilePath)

    toDownload = set(
        list(dfPairs[["id1", "t1"]].itertuples(index=False, name=None))) | set(
        list(dfPairs[["id2", "t2"]].itertuples(index=False, name=None)))
    existed = [x for x in os.listdir(waveDir) if x.endswith(".sac")]

    for x in toDownload:
        for r in dfStations.itertuples():
            if not np.isnan(r.azi):
                key = f"{x[0]}-{r.net}-{r.sta}.sac"
                if (not existed) or key not in existed:
                    try:
                        getAndSave(x[0], x[1], r.net, r.sta, r.dist)
                    except:
                        continue
    return None

getWaveform()
# Out:
# Saving us7000133-II-BORG.sac
# Saving us7000133-II-CMLA.sac
# Saving us7000133-II-ESK.sac
# Saving us7000133-II-KIV.sac
# Saving us7000133-II-SACV.sac
# Saving us7000133-IU-FURI.sac
# Saving us7000133-G-EDA.sac
# Saving us7000133-IU-LSZ.sac
# Saving us7000133-IU-TSUM.sac
# Saving us7000133-II-ASCN.sac
# Saving us7000133-G-CRZF.sac
# Saving us7000133-II-WRAB.sac
# Saving us7000133-G-TRIS.sac
# Saving us7000133-IU-CASY.sac
# Saving us7000133-II-HOPE.sac
# Saving us7000133-G-SPB.sac
# Saving us7000133-IU-TRQA.sac
# Saving us7000133-G-PEL.sac
# Saving us7000133-II-NNA.sac
# Saving us7000133-IU-SDV.sac
# Saving us7000133-CU-BBGH.sac
# Saving us7000133-CU-ANWB.sac
# Saving us7000133-IU-DWPF.sac
# Saving us7000133-IU-BBSR.sac
# Saving us7000133-IU-HRV.sac
# Saving us7000133-G-IVI.sac
# Saving us700066-II-BORG.sac
# Saving us700066-II-CMLA.sac
# Saving us700066-II-ESK.sac
# Saving us700066-II-KIV.sac
# Saving us700066-II-SACV.sac
# Saving us700066-IU-FURI.sac
# Saving us700066-G-EDA.sac
# Saving us700066-IU-LSZ.sac
# Saving us700066-II-ASCN.sac
# Saving us700066-G-CRZF.sac
# Saving us700066-II-WRAB.sac
# Saving us700066-G-TRIS.sac
# Saving us700066-IU-CASY.sac
# Saving us700066-II-HOPE.sac
# Saving us700066-G-SPB.sac
# Saving us700066-IU-TRQA.sac
# Saving us700066-G-PEL.sac
# Saving us700066-II-NNA.sac
# Saving us700066-IU-SDV.sac
# Saving us700066-CU-BBGH.sac
# Saving us700066-CU-ANWB.sac
# Saving us700066-IU-DWPF.sac
# Saving us700066-IU-BBSR.sac
# Saving us700066-IU-HRV.sac
# Saving us700066-G-IVI.sac
# Saving us700064-II-BORG.sac
# Saving us700064-II-CMLA.sac
# Saving us700064-II-ESK.sac
# Saving us700064-II-KIV.sac
# Saving us700064-II-SACV.sac
# Saving us700064-IU-FURI.sac
# Saving us700064-G-EDA.sac
# Saving us700064-IU-LSZ.sac
# Saving us700064-IU-TSUM.sac
# Saving us700064-II-ASCN.sac
# Saving us700064-G-CRZF.sac
# Saving us700064-II-WRAB.sac
# Saving us700064-G-TRIS.sac
# Saving us700064-IU-CASY.sac
# Saving us700064-II-HOPE.sac
# Saving us700064-G-SPB.sac
# Saving us700064-IU-TRQA.sac
# Saving us700064-G-PEL.sac
# Saving us700064-II-NNA.sac
# Saving us700064-IU-SDV.sac
# Saving us700064-CU-BBGH.sac
# Saving us700064-CU-ANWB.sac
# Saving us700064-IU-DWPF.sac
# Saving us700064-IU-BBSR.sac
# Saving us700064-IU-HRV.sac
# Saving us700064-G-IVI.sac
# Saving us7000131-II-BORG.sac
# Saving us7000131-II-CMLA.sac
# Saving us7000131-II-ESK.sac
# Saving us7000131-II-KIV.sac
# Saving us7000131-II-SACV.sac
# Saving us7000131-IU-FURI.sac
# Saving us7000131-G-EDA.sac
# Saving us7000131-IU-LSZ.sac
# Saving us7000131-IU-TSUM.sac
# Saving us7000131-II-ASCN.sac
# Saving us7000131-G-CRZF.sac
# Saving us7000131-II-WRAB.sac
# Saving us7000131-G-TRIS.sac
# Saving us7000131-IU-CASY.sac
# Saving us7000131-II-HOPE.sac
# Saving us7000131-G-SPB.sac
# Saving us7000131-IU-TRQA.sac
# Saving us7000131-G-PEL.sac
# Saving us7000131-II-NNA.sac
# Saving us7000131-IU-SDV.sac
# Saving us7000131-CU-BBGH.sac
# Saving us7000131-CU-ANWB.sac
# Saving us7000131-IU-DWPF.sac
# Saving us7000131-IU-BBSR.sac
# Saving us7000131-IU-HRV.sac
# Saving us7000131-G-IVI.sac
# Saving us700062-II-BORG.sac
# Saving us700062-II-CMLA.sac
# Saving us700062-II-ESK.sac
# Saving us700062-II-KIV.sac
# Saving us700062-II-SACV.sac
# Saving us700062-IU-FURI.sac
# Saving us700062-G-EDA.sac
# Saving us700062-IU-LSZ.sac
# Saving us700062-IU-TSUM.sac
# Saving us700062-II-ASCN.sac
# Saving us700062-G-CRZF.sac
# Saving us700062-II-WRAB.sac
# Saving us700062-G-TRIS.sac
# Saving us700062-IU-CASY.sac
# Saving us700062-II-HOPE.sac
# Saving us700062-G-SPB.sac
# Saving us700062-IU-TRQA.sac
# Saving us700062-G-PEL.sac
# Saving us700062-II-NNA.sac
# Saving us700062-IU-SDV.sac
# Saving us700062-CU-BBGH.sac
# Saving us700062-CU-ANWB.sac
# Saving us700062-IU-DWPF.sac
# Saving us700062-IU-BBSR.sac
# Saving us700062-IU-HRV.sac
# Saving us700062-G-IVI.sac
# Saving us7000124-II-BORG.sac
# Saving us7000124-II-CMLA.sac
# Saving us7000124-II-ESK.sac
# Saving us7000124-II-KIV.sac
# Saving us7000124-II-SACV.sac
# Saving us7000124-IU-FURI.sac
# Saving us7000124-G-EDA.sac
# Saving us7000124-IU-LSZ.sac
# Saving us7000124-IU-TSUM.sac
# Saving us7000124-II-ASCN.sac
# Saving us7000124-G-CRZF.sac
# Saving us7000124-II-WRAB.sac
# Saving us7000124-G-TRIS.sac
# Saving us7000124-IU-CASY.sac
# Saving us7000124-II-HOPE.sac
# Saving us7000124-G-SPB.sac
# Saving us7000124-IU-TRQA.sac
# Saving us7000124-G-PEL.sac
# Saving us7000124-II-NNA.sac
# Saving us7000124-IU-SDV.sac
# Saving us7000124-CU-BBGH.sac
# Saving us7000124-CU-ANWB.sac
# Saving us7000124-IU-DWPF.sac
# Saving us7000124-IU-BBSR.sac
# Saving us7000124-IU-HRV.sac
# Saving us7000124-G-IVI.sac
# Saving us700043-II-BORG.sac
# Saving us700043-II-CMLA.sac
# Saving us700043-II-ESK.sac
# Saving us700043-II-KIV.sac
# Saving us700043-II-SACV.sac
# Saving us700043-IU-FURI.sac
# Saving us700043-G-EDA.sac
# Saving us700043-IU-LSZ.sac
# Saving us700043-IU-TSUM.sac
# Saving us700043-II-ASCN.sac
# Saving us700043-G-CRZF.sac
# Saving us700043-II-WRAB.sac
# Saving us700043-G-TRIS.sac
# Saving us700043-IU-CASY.sac
# Saving us700043-II-HOPE.sac
# Saving us700043-G-SPB.sac
# Saving us700043-IU-TRQA.sac
# Saving us700043-G-PEL.sac
# Saving us700043-II-NNA.sac
# Saving us700043-IU-SDV.sac
# Saving us700043-CU-BBGH.sac
# Saving us700043-CU-ANWB.sac
# Saving us700043-IU-DWPF.sac
# Saving us700043-IU-BBSR.sac
# Saving us700043-IU-HRV.sac
# Saving us700043-G-IVI.sac
# Saving us7000109-II-BORG.sac
# Saving us7000109-II-CMLA.sac
# Saving us7000109-II-ESK.sac
# Saving us7000109-II-KIV.sac
# Saving us7000109-II-SACV.sac
# Saving us7000109-IU-FURI.sac
# Saving us7000109-G-EDA.sac
# Saving us7000109-IU-LSZ.sac
# Saving us7000109-IU-TSUM.sac
# Saving us7000109-II-ASCN.sac
# Saving us7000109-G-CRZF.sac
# Saving us7000109-II-WRAB.sac
# Saving us7000109-G-TRIS.sac
# Saving us7000109-IU-CASY.sac
# Saving us7000109-II-HOPE.sac
# Saving us7000109-G-SPB.sac
# Saving us7000109-IU-TRQA.sac
# Saving us7000109-G-PEL.sac
# Saving us7000109-II-NNA.sac
# Saving us7000109-IU-SDV.sac
# Saving us7000109-CU-BBGH.sac
# Saving us7000109-CU-ANWB.sac
# Saving us7000109-IU-DWPF.sac
# Saving us7000109-IU-BBSR.sac
# Saving us7000109-IU-HRV.sac
# Saving us7000109-G-IVI.sac
# Saving us700098-II-BORG.sac
# Saving us700098-II-CMLA.sac
# Saving us700098-II-ESK.sac
# Saving us700098-II-KIV.sac
# Saving us700098-II-SACV.sac
# Saving us700098-IU-FURI.sac
# Saving us700098-G-EDA.sac
# Saving us700098-IU-LSZ.sac
# Saving us700098-IU-TSUM.sac
# Saving us700098-II-ASCN.sac
# Saving us700098-G-CRZF.sac
# Saving us700098-II-WRAB.sac
# Saving us700098-G-TRIS.sac
# Saving us700098-IU-CASY.sac
# Saving us700098-II-HOPE.sac
# Saving us700098-G-SPB.sac
# Saving us700098-IU-TRQA.sac
# Saving us700098-G-PEL.sac
# Saving us700098-II-NNA.sac
# Saving us700098-IU-SDV.sac
# Saving us700098-CU-BBGH.sac
# Saving us700098-CU-ANWB.sac
# Saving us700098-IU-DWPF.sac
# Saving us700098-IU-BBSR.sac
# Saving us700098-IU-HRV.sac
# Saving us700098-G-IVI.sac
# Saving us700034-II-BORG.sac
# Saving us700034-II-CMLA.sac
# Saving us700034-II-ESK.sac
# Saving us700034-II-KIV.sac
# Saving us700034-II-SACV.sac
# Saving us700034-IU-FURI.sac
# Saving us700034-G-EDA.sac
# Saving us700034-IU-LSZ.sac
# Saving us700034-IU-TSUM.sac
# Saving us700034-II-ASCN.sac
# Saving us700034-G-CRZF.sac
# Saving us700034-II-WRAB.sac
# Saving us700034-G-TRIS.sac
# Saving us700034-IU-CASY.sac
# Saving us700034-II-HOPE.sac
# Saving us700034-G-SPB.sac
# Saving us700034-IU-TRQA.sac
# Saving us700034-G-PEL.sac
# Saving us700034-II-NNA.sac
# Saving us700034-IU-SDV.sac
# Saving us700034-CU-BBGH.sac
# Saving us700034-CU-ANWB.sac
# Saving us700034-IU-DWPF.sac
# Saving us700034-IU-BBSR.sac
# Saving us700034-IU-HRV.sac
# Saving us700034-G-IVI.sac
# Saving us700058-II-BORG.sac
# Saving us700058-II-CMLA.sac
# Saving us700058-II-ESK.sac
# Saving us700058-II-KIV.sac
# Saving us700058-II-SACV.sac
# Saving us700058-IU-FURI.sac
# Saving us700058-G-EDA.sac
# Saving us700058-IU-LSZ.sac
# Saving us700058-IU-TSUM.sac
# Saving us700058-II-ASCN.sac
# Saving us700058-G-CRZF.sac
# Saving us700058-II-WRAB.sac
# Saving us700058-G-TRIS.sac
# Saving us700058-IU-CASY.sac
# Saving us700058-II-HOPE.sac
# Saving us700058-G-SPB.sac
# Saving us700058-IU-TRQA.sac
# Saving us700058-G-PEL.sac
# Saving us700058-II-NNA.sac
# Saving us700058-IU-SDV.sac
# Saving us700058-CU-BBGH.sac
# Saving us700058-CU-ANWB.sac
# Saving us700058-IU-DWPF.sac
# Saving us700058-IU-BBSR.sac
# Saving us700058-IU-HRV.sac
# Saving us700058-G-IVI.sac
# Saving us700097-II-BORG.sac
# Saving us700097-II-CMLA.sac
# Saving us700097-II-ESK.sac
# Saving us700097-II-KIV.sac
# Saving us700097-II-SACV.sac
# Saving us700097-IU-FURI.sac
# Saving us700097-G-EDA.sac
# Saving us700097-IU-LSZ.sac
# Saving us700097-IU-TSUM.sac
# Saving us700097-II-ASCN.sac
# Saving us700097-G-CRZF.sac
# Saving us700097-II-WRAB.sac
# Saving us700097-G-TRIS.sac
# Saving us700097-IU-CASY.sac
# Saving us700097-II-HOPE.sac
# Saving us700097-G-SPB.sac
# Saving us700097-IU-TRQA.sac
# Saving us700097-G-PEL.sac
# Saving us700097-II-NNA.sac
# Saving us700097-IU-SDV.sac
# Saving us700097-CU-BBGH.sac
# Saving us700097-CU-ANWB.sac
# Saving us700097-IU-DWPF.sac
# Saving us700097-IU-BBSR.sac
# Saving us700097-IU-HRV.sac
# Saving us700097-G-IVI.sac
# Saving us7000112-II-BORG.sac
# Saving us7000112-II-CMLA.sac
# Saving us7000112-II-ESK.sac
# Saving us7000112-II-KIV.sac
# Saving us7000112-II-SACV.sac
# Saving us7000112-IU-FURI.sac
# Saving us7000112-G-EDA.sac
# Saving us7000112-IU-LSZ.sac
# Saving us7000112-IU-TSUM.sac
# Saving us7000112-II-ASCN.sac
# Saving us7000112-G-CRZF.sac
# Saving us7000112-II-WRAB.sac
# Saving us7000112-G-TRIS.sac
# Saving us7000112-IU-CASY.sac
# Saving us7000112-II-HOPE.sac
# Saving us7000112-G-SPB.sac
# Saving us7000112-IU-TRQA.sac
# Saving us7000112-G-PEL.sac
# Saving us7000112-II-NNA.sac
# Saving us7000112-IU-SDV.sac
# Saving us7000112-CU-BBGH.sac
# Saving us7000112-CU-ANWB.sac
# Saving us7000112-IU-DWPF.sac
# Saving us7000112-IU-BBSR.sac
# Saving us7000112-IU-HRV.sac
# Saving us7000112-G-IVI.sac
# Saving us7000101-II-BORG.sac
# Saving us7000101-II-CMLA.sac
# Saving us7000101-II-ESK.sac
# Saving us7000101-II-KIV.sac
# Saving us7000101-II-SACV.sac
# Saving us7000101-IU-FURI.sac
# Saving us7000101-G-EDA.sac
# Saving us7000101-IU-LSZ.sac
# Saving us7000101-IU-TSUM.sac
# Saving us7000101-II-ASCN.sac
# Saving us7000101-G-CRZF.sac
# Saving us7000101-II-WRAB.sac
# Saving us7000101-G-TRIS.sac
# Saving us7000101-IU-CASY.sac
# Saving us7000101-II-HOPE.sac
# Saving us7000101-G-SPB.sac
# Saving us7000101-IU-TRQA.sac
# Saving us7000101-G-PEL.sac
# Saving us7000101-II-NNA.sac
# Saving us7000101-IU-SDV.sac
# Saving us7000101-CU-BBGH.sac
# Saving us7000101-CU-ANWB.sac
# Saving us7000101-IU-DWPF.sac
# Saving us7000101-IU-BBSR.sac
# Saving us7000101-IU-HRV.sac
# Saving us7000101-G-IVI.sac
# Saving us700077-II-BORG.sac
# Saving us700077-II-CMLA.sac
# Saving us700077-II-ESK.sac
# Saving us700077-II-KIV.sac
# Saving us700077-II-SACV.sac
# Saving us700077-IU-FURI.sac
# Saving us700077-G-EDA.sac
# Saving us700077-IU-LSZ.sac
# Saving us700077-IU-TSUM.sac
# Saving us700077-II-ASCN.sac
# Saving us700077-G-CRZF.sac
# Saving us700077-II-WRAB.sac
# Saving us700077-G-TRIS.sac
# Saving us700077-IU-CASY.sac
# Saving us700077-II-HOPE.sac
# Saving us700077-G-SPB.sac
# Saving us700077-IU-TRQA.sac
# Saving us700077-G-PEL.sac
# Saving us700077-II-NNA.sac
# Saving us700077-IU-SDV.sac
# Saving us700077-CU-BBGH.sac
# Saving us700077-CU-ANWB.sac
# Saving us700077-IU-DWPF.sac
# Saving us700077-IU-BBSR.sac
# Saving us700077-IU-HRV.sac
# Saving us700077-G-IVI.sac
# Saving us700050-II-BORG.sac
# Saving us700050-II-CMLA.sac
# Saving us700050-II-ESK.sac
# Saving us700050-II-KIV.sac
# Saving us700050-II-SACV.sac
# Saving us700050-IU-FURI.sac
# Saving us700050-G-EDA.sac
# Saving us700050-IU-LSZ.sac
# Saving us700050-IU-TSUM.sac
# Saving us700050-II-ASCN.sac
# Saving us700050-G-CRZF.sac
# Saving us700050-II-WRAB.sac
# Saving us700050-G-TRIS.sac
# Saving us700050-IU-CASY.sac
# Saving us700050-II-HOPE.sac
# Saving us700050-G-SPB.sac
# Saving us700050-IU-TRQA.sac
# Saving us700050-G-PEL.sac
# Saving us700050-II-NNA.sac
# Saving us700050-IU-SDV.sac
# Saving us700050-CU-BBGH.sac
# Saving us700050-CU-ANWB.sac
# Saving us700050-IU-DWPF.sac
# Saving us700050-IU-BBSR.sac
# Saving us700050-IU-HRV.sac
# Saving us700050-G-IVI.sac
# Saving us700045-II-BORG.sac
# Saving us700045-II-CMLA.sac
# Saving us700045-II-ESK.sac
# Saving us700045-II-KIV.sac
# Saving us700045-II-SACV.sac
# Saving us700045-IU-FURI.sac
# Saving us700045-G-EDA.sac
# Saving us700045-IU-LSZ.sac
# Saving us700045-IU-TSUM.sac
# Saving us700045-II-ASCN.sac
# Saving us700045-G-CRZF.sac
# Saving us700045-II-WRAB.sac
# Saving us700045-G-TRIS.sac
# Saving us700045-IU-CASY.sac
# Saving us700045-II-HOPE.sac
# Saving us700045-G-SPB.sac
# Saving us700045-IU-TRQA.sac
# Saving us700045-G-PEL.sac
# Saving us700045-II-NNA.sac
# Saving us700045-IU-SDV.sac
# Saving us700045-CU-BBGH.sac
# Saving us700045-CU-ANWB.sac
# Saving us700045-IU-DWPF.sac
# Saving us700045-IU-BBSR.sac
# Saving us700045-IU-HRV.sac
# Saving us700045-G-IVI.sac
# Saving us700032-II-BORG.sac
# Saving us700032-II-CMLA.sac
# Saving us700032-II-ESK.sac
# Saving us700032-II-KIV.sac
# Saving us700032-II-SACV.sac
# Saving us700032-IU-FURI.sac
# Saving us700032-G-EDA.sac
# Saving us700032-IU-LSZ.sac
# Saving us700032-IU-TSUM.sac
# Saving us700032-II-ASCN.sac
# Saving us700032-G-CRZF.sac
# Saving us700032-II-WRAB.sac
# Saving us700032-G-TRIS.sac
# Saving us700032-IU-CASY.sac
# Saving us700032-II-HOPE.sac
# Saving us700032-G-SPB.sac
# Saving us700032-IU-TRQA.sac
# Saving us700032-G-PEL.sac
# Saving us700032-II-NNA.sac
# Saving us700032-IU-SDV.sac
# Saving us700032-CU-BBGH.sac
# Saving us700032-CU-ANWB.sac
# Saving us700032-IU-DWPF.sac
# Saving us700032-IU-BBSR.sac
# Saving us700032-IU-HRV.sac
# Saving us700032-G-IVI.sac
# Saving us700051-II-BORG.sac
# Saving us700051-II-CMLA.sac
# Saving us700051-II-ESK.sac
# Saving us700051-II-KIV.sac
# Saving us700051-II-SACV.sac
# Saving us700051-IU-FURI.sac
# Saving us700051-G-EDA.sac
# Saving us700051-IU-LSZ.sac
# Saving us700051-IU-TSUM.sac
# Saving us700051-II-ASCN.sac
# Saving us700051-G-CRZF.sac
# Saving us700051-II-WRAB.sac
# Saving us700051-G-TRIS.sac
# Saving us700051-IU-CASY.sac
# Saving us700051-II-HOPE.sac
# Saving us700051-G-SPB.sac
# Saving us700051-IU-TRQA.sac
# Saving us700051-G-PEL.sac
# Saving us700051-II-NNA.sac
# Saving us700051-IU-SDV.sac
# Saving us700051-CU-BBGH.sac
# Saving us700051-CU-ANWB.sac
# Saving us700051-IU-DWPF.sac
# Saving us700051-IU-BBSR.sac
# Saving us700051-IU-HRV.sac
# Saving us700051-G-IVI.sac
# Saving us700042-II-BORG.sac
# Saving us700042-II-CMLA.sac
# Saving us700042-II-ESK.sac
# Saving us700042-II-KIV.sac
# Saving us700042-II-SACV.sac
# Saving us700042-IU-FURI.sac
# Saving us700042-G-EDA.sac
# Saving us700042-IU-LSZ.sac
# Saving us700042-IU-TSUM.sac
# Saving us700042-II-ASCN.sac
# Saving us700042-G-CRZF.sac
# Saving us700042-II-WRAB.sac
# Saving us700042-G-TRIS.sac
# Saving us700042-IU-CASY.sac
# Saving us700042-II-HOPE.sac
# Saving us700042-G-SPB.sac
# Saving us700042-IU-TRQA.sac
# Saving us700042-G-PEL.sac
# Saving us700042-II-NNA.sac
# Saving us700042-IU-SDV.sac
# Saving us700042-CU-BBGH.sac
# Saving us700042-CU-ANWB.sac
# Saving us700042-IU-DWPF.sac
# Saving us700042-IU-BBSR.sac
# Saving us700042-IU-HRV.sac
# Saving us700042-G-IVI.sac
# Saving us700027-II-BORG.sac
# Saving us700027-II-CMLA.sac
# Saving us700027-II-ESK.sac
# Saving us700027-II-KIV.sac
# Saving us700027-II-SACV.sac
# Saving us700027-IU-FURI.sac
# Saving us700027-G-EDA.sac
# Saving us700027-IU-LSZ.sac
# Saving us700027-IU-TSUM.sac
# Saving us700027-II-ASCN.sac
# Saving us700027-G-CRZF.sac
# Saving us700027-II-WRAB.sac
# Saving us700027-G-TRIS.sac
# Saving us700027-IU-CASY.sac
# Saving us700027-II-HOPE.sac
# Saving us700027-G-SPB.sac
# Saving us700027-IU-TRQA.sac
# Saving us700027-G-PEL.sac
# Saving us700027-II-NNA.sac
# Saving us700027-IU-SDV.sac
# Saving us700027-CU-BBGH.sac
# Saving us700027-CU-ANWB.sac
# Saving us700027-IU-DWPF.sac
# Saving us700027-IU-BBSR.sac
# Saving us700027-IU-HRV.sac
# Saving us700027-G-IVI.sac
# Saving us700096-II-BORG.sac
# Saving us700096-II-CMLA.sac
# Saving us700096-II-ESK.sac
# Saving us700096-II-KIV.sac
# Saving us700096-II-SACV.sac
# Saving us700096-IU-FURI.sac
# Saving us700096-G-EDA.sac
# Saving us700096-IU-LSZ.sac
# Saving us700096-IU-TSUM.sac
# Saving us700096-II-ASCN.sac
# Saving us700096-G-CRZF.sac
# Saving us700096-II-WRAB.sac
# Saving us700096-G-TRIS.sac
# Saving us700096-IU-CASY.sac
# Saving us700096-II-HOPE.sac
# Saving us700096-G-SPB.sac
# Saving us700096-IU-TRQA.sac
# Saving us700096-G-PEL.sac
# Saving us700096-II-NNA.sac
# Saving us700096-IU-SDV.sac
# Saving us700096-CU-BBGH.sac
# Saving us700096-CU-ANWB.sac
# Saving us700096-IU-DWPF.sac
# Saving us700096-IU-BBSR.sac
# Saving us700096-IU-HRV.sac
# Saving us700096-G-IVI.sac
# Saving us700054-II-BORG.sac
# Saving us700054-II-CMLA.sac
# Saving us700054-II-ESK.sac
# Saving us700054-II-KIV.sac
# Saving us700054-II-SACV.sac
# Saving us700054-IU-FURI.sac
# Saving us700054-G-EDA.sac
# Saving us700054-IU-LSZ.sac
# Saving us700054-IU-TSUM.sac
# Saving us700054-II-ASCN.sac
# Saving us700054-G-CRZF.sac
# Saving us700054-II-WRAB.sac
# Saving us700054-G-TRIS.sac
# Saving us700054-IU-CASY.sac
# Saving us700054-II-HOPE.sac
# Saving us700054-G-SPB.sac
# Saving us700054-IU-TRQA.sac
# Saving us700054-G-PEL.sac
# Saving us700054-II-NNA.sac
# Saving us700054-IU-SDV.sac
# Saving us700054-CU-BBGH.sac
# Saving us700054-CU-ANWB.sac
# Saving us700054-IU-DWPF.sac
# Saving us700054-IU-BBSR.sac
# Saving us700054-IU-HRV.sac
# Saving us700054-G-IVI.sac
# Saving us700041-II-BORG.sac
# Saving us700041-II-CMLA.sac
# Saving us700041-II-ESK.sac
# Saving us700041-II-KIV.sac
# Saving us700041-II-SACV.sac
# Saving us700041-IU-FURI.sac
# Saving us700041-G-EDA.sac
# Saving us700041-IU-LSZ.sac
# Saving us700041-IU-TSUM.sac
# Saving us700041-II-ASCN.sac
# Saving us700041-G-CRZF.sac
# Saving us700041-II-WRAB.sac
# Saving us700041-G-TRIS.sac
# Saving us700041-IU-CASY.sac
# Saving us700041-II-HOPE.sac
# Saving us700041-G-SPB.sac
# Saving us700041-IU-TRQA.sac
# Saving us700041-G-PEL.sac
# Saving us700041-II-NNA.sac
# Saving us700041-IU-SDV.sac
# Saving us700041-CU-BBGH.sac
# Saving us700041-CU-ANWB.sac
# Saving us700041-IU-DWPF.sac
# Saving us700041-IU-BBSR.sac
# Saving us700041-IU-HRV.sac
# Saving us700041-G-IVI.sac
# Saving us700044-II-BORG.sac
# Saving us700044-II-CMLA.sac
# Saving us700044-II-ESK.sac
# Saving us700044-II-KIV.sac
# Saving us700044-II-SACV.sac
# Saving us700044-IU-FURI.sac
# Saving us700044-G-EDA.sac
# Saving us700044-IU-LSZ.sac
# Saving us700044-IU-TSUM.sac
# Saving us700044-II-ASCN.sac
# Saving us700044-G-CRZF.sac
# Saving us700044-II-WRAB.sac
# Saving us700044-G-TRIS.sac
# Saving us700044-IU-CASY.sac
# Saving us700044-II-HOPE.sac
# Saving us700044-G-SPB.sac
# Saving us700044-IU-TRQA.sac
# Saving us700044-G-PEL.sac
# Saving us700044-II-NNA.sac
# Saving us700044-IU-SDV.sac
# Saving us700044-CU-BBGH.sac
# Saving us700044-CU-ANWB.sac
# Saving us700044-IU-DWPF.sac
# Saving us700044-IU-BBSR.sac
# Saving us700044-IU-HRV.sac
# Saving us700044-G-IVI.sac
# Saving us700052-II-BORG.sac
# Saving us700052-II-CMLA.sac
# Saving us700052-II-ESK.sac
# Saving us700052-II-KIV.sac
# Saving us700052-II-SACV.sac
# Saving us700052-IU-FURI.sac
# Saving us700052-G-EDA.sac
# Saving us700052-IU-LSZ.sac
# Saving us700052-IU-TSUM.sac
# Saving us700052-II-ASCN.sac
# Saving us700052-G-CRZF.sac
# Saving us700052-II-WRAB.sac
# Saving us700052-G-TRIS.sac
# Saving us700052-IU-CASY.sac
# Saving us700052-II-HOPE.sac
# Saving us700052-G-SPB.sac
# Saving us700052-IU-TRQA.sac
# Saving us700052-G-PEL.sac
# Saving us700052-II-NNA.sac
# Saving us700052-IU-SDV.sac
# Saving us700052-CU-BBGH.sac
# Saving us700052-CU-ANWB.sac
# Saving us700052-IU-DWPF.sac
# Saving us700052-IU-BBSR.sac
# Saving us700052-IU-HRV.sac
# Saving us700052-G-IVI.sac
# Saving us7000127-II-BORG.sac
# Saving us7000127-II-CMLA.sac
# Saving us7000127-II-ESK.sac
# Saving us7000127-II-KIV.sac
# Saving us7000127-II-SACV.sac
# Saving us7000127-IU-FURI.sac
# Saving us7000127-G-EDA.sac
# Saving us7000127-IU-LSZ.sac
# Saving us7000127-IU-TSUM.sac
# Saving us7000127-II-ASCN.sac
# Saving us7000127-G-CRZF.sac
# Saving us7000127-II-WRAB.sac
# Saving us7000127-G-TRIS.sac
# Saving us7000127-IU-CASY.sac
# Saving us7000127-II-HOPE.sac
# Saving us7000127-G-SPB.sac
# Saving us7000127-IU-TRQA.sac
# Saving us7000127-G-PEL.sac
# Saving us7000127-II-NNA.sac
# Saving us7000127-IU-SDV.sac
# Saving us7000127-CU-BBGH.sac
# Saving us7000127-CU-ANWB.sac
# Saving us7000127-IU-DWPF.sac
# Saving us7000127-IU-BBSR.sac
# Saving us7000127-IU-HRV.sac
# Saving us7000127-G-IVI.sac
# Saving us700039-II-BORG.sac
# Saving us700039-II-CMLA.sac
# Saving us700039-II-ESK.sac
# Saving us700039-II-KIV.sac
# Saving us700039-II-SACV.sac
# Saving us700039-IU-FURI.sac
# Saving us700039-G-EDA.sac
# Saving us700039-IU-LSZ.sac
# Saving us700039-IU-TSUM.sac
# Saving us700039-II-ASCN.sac
# Saving us700039-G-CRZF.sac
# Saving us700039-II-WRAB.sac
# Saving us700039-G-TRIS.sac
# Saving us700039-IU-CASY.sac
# Saving us700039-II-HOPE.sac
# Saving us700039-G-SPB.sac
# Saving us700039-IU-TRQA.sac
# Saving us700039-G-PEL.sac
# Saving us700039-II-NNA.sac
# Saving us700039-IU-SDV.sac
# Saving us700039-CU-BBGH.sac
# Saving us700039-CU-ANWB.sac
# Saving us700039-IU-DWPF.sac
# Saving us700039-IU-BBSR.sac
# Saving us700039-IU-HRV.sac
# Saving us700039-G-IVI.sac
# Saving us700089-II-BORG.sac
# Saving us700089-II-CMLA.sac
# Saving us700089-II-ESK.sac
# Saving us700089-II-KIV.sac
# Saving us700089-II-SACV.sac
# Saving us700089-IU-FURI.sac
# Saving us700089-G-EDA.sac
# Saving us700089-IU-LSZ.sac
# Saving us700089-IU-TSUM.sac
# Saving us700089-II-ASCN.sac
# Saving us700089-G-CRZF.sac
# Saving us700089-II-WRAB.sac
# Saving us700089-G-TRIS.sac
# Saving us700089-IU-CASY.sac
# Saving us700089-II-HOPE.sac
# Saving us700089-G-SPB.sac
# Saving us700089-IU-TRQA.sac
# Saving us700089-G-PEL.sac
# Saving us700089-II-NNA.sac
# Saving us700089-IU-SDV.sac
# Saving us700089-CU-BBGH.sac
# Saving us700089-CU-ANWB.sac
# Saving us700089-IU-DWPF.sac
# Saving us700089-IU-BBSR.sac
# Saving us700089-IU-HRV.sac
# Saving us700089-G-IVI.sac
# Saving us700049-II-BORG.sac
# Saving us700049-II-CMLA.sac
# Saving us700049-II-ESK.sac
# Saving us700049-II-KIV.sac
# Saving us700049-II-SACV.sac
# Saving us700049-IU-FURI.sac
# Saving us700049-G-EDA.sac
# Saving us700049-IU-LSZ.sac
# Saving us700049-IU-TSUM.sac
# Saving us700049-II-ASCN.sac
# Saving us700049-G-CRZF.sac
# Saving us700049-II-WRAB.sac
# Saving us700049-G-TRIS.sac
# Saving us700049-IU-CASY.sac
# Saving us700049-II-HOPE.sac
# Saving us700049-G-SPB.sac
# Saving us700049-IU-TRQA.sac
# Saving us700049-G-PEL.sac
# Saving us700049-II-NNA.sac
# Saving us700049-IU-SDV.sac
# Saving us700049-CU-BBGH.sac
# Saving us700049-CU-ANWB.sac
# Saving us700049-IU-DWPF.sac
# Saving us700049-IU-BBSR.sac
# Saving us700049-IU-HRV.sac
# Saving us700049-G-IVI.sac
# Saving us7000130-II-BORG.sac
# Saving us7000130-II-CMLA.sac
# Saving us7000130-II-ESK.sac
# Saving us7000130-II-KIV.sac
# Saving us7000130-II-SACV.sac
# Saving us7000130-IU-FURI.sac
# Saving us7000130-G-EDA.sac
# Saving us7000130-IU-LSZ.sac
# Saving us7000130-IU-TSUM.sac
# Saving us7000130-II-ASCN.sac
# Saving us7000130-G-CRZF.sac
# Saving us7000130-II-WRAB.sac
# Saving us7000130-G-TRIS.sac
# Saving us7000130-IU-CASY.sac
# Saving us7000130-II-HOPE.sac
# Saving us7000130-G-SPB.sac
# Saving us7000130-IU-TRQA.sac
# Saving us7000130-G-PEL.sac
# Saving us7000130-II-NNA.sac
# Saving us7000130-IU-SDV.sac
# Saving us7000130-CU-BBGH.sac
# Saving us7000130-CU-ANWB.sac
# Saving us7000130-IU-DWPF.sac
# Saving us7000130-IU-BBSR.sac
# Saving us7000130-IU-HRV.sac
# Saving us7000130-G-IVI.sac
# Saving us700048-II-BORG.sac
# Saving us700048-II-CMLA.sac
# Saving us700048-II-ESK.sac
# Saving us700048-II-KIV.sac
# Saving us700048-II-SACV.sac
# Saving us700048-IU-FURI.sac
# Saving us700048-G-EDA.sac
# Saving us700048-IU-LSZ.sac
# d:\Users\student\anaconda3\lib\site-packages\obspy\clients\fdsn\client.py:909: UserWarning: Unknown Error (URLError): <urlopen error [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond>
#   warnings.warn(str(e))
# d:\Users\student\anaconda3\lib\site-packages\obspy\core\stream.py:3197: UserWarning: No matching response information found.
#   warnings.warn(str(e))
# Saving us700048-IU-TSUM.sac
# Saving us700048-II-ASCN.sac
# Saving us700048-G-CRZF.sac
# Saving us700048-II-WRAB.sac
# Saving us700048-G-TRIS.sac
# Saving us700048-IU-CASY.sac
# Saving us700048-II-HOPE.sac
# Saving us700048-G-SPB.sac
# Saving us700048-IU-TRQA.sac
# Saving us700048-G-PEL.sac
# Saving us700048-II-NNA.sac
# Saving us700048-IU-SDV.sac
# Saving us700048-CU-BBGH.sac
# Saving us700048-CU-ANWB.sac
# Saving us700048-IU-DWPF.sac
# Saving us700048-IU-BBSR.sac
# Saving us700048-IU-HRV.sac
# Saving us700048-G-IVI.sac
# Saving us700079-II-BORG.sac
# Saving us700079-II-CMLA.sac
# Saving us700079-II-ESK.sac
# Saving us700079-II-KIV.sac
# Saving us700079-II-SACV.sac
# Saving us700079-IU-FURI.sac
# Saving us700079-G-EDA.sac
# Saving us700079-IU-LSZ.sac
# Saving us700079-IU-TSUM.sac
# Saving us700079-II-ASCN.sac
# Saving us700079-G-CRZF.sac
# Saving us700079-II-WRAB.sac
# Saving us700079-G-TRIS.sac
# Saving us700079-II-HOPE.sac
# Saving us700079-G-SPB.sac
# Saving us700079-IU-TRQA.sac
# Saving us700079-G-PEL.sac
# Saving us700079-II-NNA.sac
# Saving us700079-IU-SDV.sac
# Saving us700079-CU-BBGH.sac
# Saving us700079-CU-ANWB.sac
# Saving us700079-IU-DWPF.sac
# Saving us700079-IU-BBSR.sac
# Saving us700079-IU-HRV.sac
# Saving us700079-G-IVI.sac
# Saving us700046-II-BORG.sac
# Saving us700046-II-CMLA.sac
# Saving us700046-II-ESK.sac
# Saving us700046-II-KIV.sac
# Saving us700046-II-SACV.sac
# Saving us700046-IU-FURI.sac
# Saving us700046-G-EDA.sac
# Saving us700046-IU-LSZ.sac
# Saving us700046-IU-TSUM.sac
# Saving us700046-II-ASCN.sac
# Saving us700046-G-CRZF.sac
# Saving us700046-II-WRAB.sac
# Saving us700046-G-TRIS.sac
# Saving us700046-IU-CASY.sac
# Saving us700046-II-HOPE.sac
# Saving us700046-G-SPB.sac
# Saving us700046-IU-TRQA.sac
# Saving us700046-G-PEL.sac
# Saving us700046-II-NNA.sac
# Saving us700046-IU-SDV.sac
# Saving us700046-CU-BBGH.sac
# Saving us700046-CU-ANWB.sac
# Saving us700046-IU-DWPF.sac
# Saving us700046-IU-BBSR.sac
# Saving us700046-IU-HRV.sac
# Saving us700046-G-IVI.sac
# Saving us7000118-II-BORG.sac
# Saving us7000118-II-CMLA.sac
# Saving us7000118-II-ESK.sac
# Saving us7000118-II-KIV.sac
# Saving us7000118-II-SACV.sac
# Saving us7000118-IU-FURI.sac
# Saving us7000118-G-EDA.sac
# Saving us7000118-IU-LSZ.sac
# Saving us7000118-IU-TSUM.sac
# Saving us7000118-II-ASCN.sac
# Saving us7000118-G-CRZF.sac
# Saving us7000118-II-WRAB.sac
# Saving us7000118-G-TRIS.sac
# Saving us7000118-IU-CASY.sac
# Saving us7000118-II-HOPE.sac
# Saving us7000118-G-SPB.sac
# Saving us7000118-IU-TRQA.sac
# Saving us7000118-G-PEL.sac
# Saving us7000118-II-NNA.sac
# Saving us7000118-IU-SDV.sac
# Saving us7000118-CU-BBGH.sac
# Saving us7000118-CU-ANWB.sac
# Saving us7000118-IU-DWPF.sac
# Saving us7000118-IU-BBSR.sac
# Saving us7000118-IU-HRV.sac
# Saving us7000118-G-IVI.sac
# Saving us7000122-II-BORG.sac
# Saving us7000122-II-CMLA.sac
# Saving us7000122-II-ESK.sac
# Saving us7000122-II-KIV.sac
# Saving us7000122-II-SACV.sac
# Saving us7000122-IU-FURI.sac
# Saving us7000122-G-EDA.sac
# Saving us7000122-IU-LSZ.sac
# Saving us7000122-IU-TSUM.sac
# Saving us7000122-II-ASCN.sac
# Saving us7000122-G-CRZF.sac
# Saving us7000122-II-WRAB.sac
# Saving us7000122-G-TRIS.sac
# Saving us7000122-IU-CASY.sac
# Saving us7000122-II-HOPE.sac
# Saving us7000122-G-SPB.sac
# Saving us7000122-IU-TRQA.sac
# Saving us7000122-G-PEL.sac
# Saving us7000122-II-NNA.sac
# Saving us7000122-IU-SDV.sac
# Saving us7000122-CU-BBGH.sac
# Saving us7000122-CU-ANWB.sac
# Saving us7000122-IU-DWPF.sac
# Saving us7000122-IU-BBSR.sac
# Saving us7000122-IU-HRV.sac
# Saving us7000122-G-IVI.sac
# Saving us7000104-II-BORG.sac
# Saving us7000104-II-CMLA.sac
# Saving us7000104-II-ESK.sac
# Saving us7000104-II-KIV.sac
# Saving us7000104-II-SACV.sac
# Saving us7000104-IU-FURI.sac
# Saving us7000104-G-EDA.sac
# Saving us7000104-IU-LSZ.sac
# Saving us7000104-IU-TSUM.sac
# Saving us7000104-II-ASCN.sac
# Saving us7000104-G-CRZF.sac
# Saving us7000104-II-WRAB.sac
# Saving us7000104-G-TRIS.sac
# Saving us7000104-IU-CASY.sac
# Saving us7000104-II-HOPE.sac
# Saving us7000104-G-SPB.sac
# Saving us7000104-IU-TRQA.sac
# Saving us7000104-G-PEL.sac
# Saving us7000104-II-NNA.sac
# Saving us7000104-IU-SDV.sac
# Saving us7000104-CU-BBGH.sac
# Saving us7000104-CU-ANWB.sac
# Saving us7000104-IU-DWPF.sac
# Saving us7000104-IU-BBSR.sac
# Saving us7000104-IU-HRV.sac
# Saving us7000104-G-IVI.sac
# Saving us7000128-II-BORG.sac
# Saving us7000128-II-CMLA.sac
# Saving us7000128-II-ESK.sac
# Saving us7000128-II-KIV.sac
# Saving us7000128-II-SACV.sac
# Saving us7000128-IU-FURI.sac
# Saving us7000128-G-EDA.sac
# Saving us7000128-IU-LSZ.sac
# Saving us7000128-IU-TSUM.sac
# Saving us7000128-II-ASCN.sac
# Saving us7000128-G-CRZF.sac
# Saving us7000128-II-WRAB.sac
# Saving us7000128-G-TRIS.sac
# Saving us7000128-IU-CASY.sac
# Saving us7000128-II-HOPE.sac
# Saving us7000128-G-SPB.sac
# Saving us7000128-IU-TRQA.sac
# Saving us7000128-G-PEL.sac
# Saving us7000128-II-NNA.sac
# Saving us7000128-IU-SDV.sac
# Saving us7000128-CU-BBGH.sac
# Saving us7000128-CU-ANWB.sac
# Saving us7000128-IU-DWPF.sac
# Saving us7000128-IU-BBSR.sac
# Saving us7000128-IU-HRV.sac
# Saving us7000128-G-IVI.sac
# Saving us700031-II-BORG.sac
# Saving us700031-II-CMLA.sac
# Saving us700031-II-ESK.sac
# Saving us700031-II-KIV.sac
# Saving us700031-II-SACV.sac
# Saving us700031-IU-FURI.sac
# Saving us700031-G-EDA.sac
# Saving us700031-IU-LSZ.sac
# Saving us700031-IU-TSUM.sac
# Saving us700031-II-ASCN.sac
# Saving us700031-G-CRZF.sac
# Saving us700031-II-WRAB.sac
# Saving us700031-G-TRIS.sac
# Saving us700031-IU-CASY.sac
# Saving us700031-II-HOPE.sac
# Saving us700031-G-SPB.sac
# Saving us700031-IU-TRQA.sac
# Saving us700031-G-PEL.sac
# Saving us700031-II-NNA.sac
# Saving us700031-IU-SDV.sac
# Saving us700031-CU-BBGH.sac
# Saving us700031-CU-ANWB.sac
# Saving us700031-IU-DWPF.sac
# Saving us700031-IU-BBSR.sac
# Saving us700031-IU-HRV.sac
# Saving us700031-G-IVI.sac
# Saving us7000106-II-BORG.sac
# Saving us7000106-II-CMLA.sac
# Saving us7000106-II-ESK.sac
# Saving us7000106-II-KIV.sac
# Saving us7000106-II-SACV.sac
# Saving us7000106-IU-FURI.sac
# Saving us7000106-G-EDA.sac
# Saving us7000106-IU-LSZ.sac
# Saving us7000106-IU-TSUM.sac
# Saving us7000106-II-ASCN.sac
# Saving us7000106-G-CRZF.sac
# Saving us7000106-II-WRAB.sac
# Saving us7000106-G-TRIS.sac
# Saving us7000106-IU-CASY.sac
# Saving us7000106-II-HOPE.sac
# Saving us7000106-G-SPB.sac
# Saving us7000106-IU-TRQA.sac
# Saving us7000106-G-PEL.sac
# Saving us7000106-II-NNA.sac
# Saving us7000106-IU-SDV.sac
# Saving us7000106-CU-BBGH.sac
# Saving us7000106-CU-ANWB.sac
# Saving us7000106-IU-DWPF.sac
# Saving us7000106-IU-BBSR.sac
# Saving us7000106-IU-HRV.sac
# Saving us7000106-G-IVI.sac
# Saving us700040-II-BORG.sac
# Saving us700040-II-CMLA.sac
# Saving us700040-II-ESK.sac
# Saving us700040-II-KIV.sac
# Saving us700040-II-SACV.sac
# Saving us700040-IU-FURI.sac
# Saving us700040-G-EDA.sac
# Saving us700040-IU-LSZ.sac
# Saving us700040-IU-TSUM.sac
# Saving us700040-II-ASCN.sac
# Saving us700040-G-CRZF.sac
# Saving us700040-II-WRAB.sac
# Saving us700040-G-TRIS.sac
# Saving us700040-IU-CASY.sac
# Saving us700040-II-HOPE.sac
# Saving us700040-G-SPB.sac
# Saving us700040-IU-TRQA.sac
# Saving us700040-G-PEL.sac
# Saving us700040-II-NNA.sac
# Saving us700040-IU-SDV.sac
# Saving us700040-CU-BBGH.sac
# Saving us700040-CU-ANWB.sac
# Saving us700040-IU-DWPF.sac
# Saving us700040-IU-BBSR.sac
# Saving us700040-IU-HRV.sac
# Saving us700040-G-IVI.sac
# Saving us700065-II-BORG.sac
# Saving us700065-II-CMLA.sac
# Saving us700065-II-ESK.sac
# Saving us700065-II-KIV.sac
# Saving us700065-II-SACV.sac
# Saving us700065-IU-FURI.sac
# Saving us700065-G-EDA.sac
# Saving us700065-IU-LSZ.sac
# Saving us700065-IU-TSUM.sac
# Saving us700065-II-ASCN.sac
# Saving us700065-G-CRZF.sac
# Saving us700065-II-WRAB.sac
# Saving us700065-G-TRIS.sac
# Saving us700065-IU-CASY.sac
# Saving us700065-II-HOPE.sac
# Saving us700065-G-SPB.sac
# Saving us700065-IU-TRQA.sac
# Saving us700065-G-PEL.sac
# Saving us700065-II-NNA.sac
# Saving us700065-IU-SDV.sac
# Saving us700065-CU-BBGH.sac
# Saving us700065-CU-ANWB.sac
# Saving us700065-IU-DWPF.sac
# Saving us700065-IU-BBSR.sac
# Saving us700065-IU-HRV.sac
# Saving us700065-G-IVI.sac
# Saving us700069-II-BORG.sac
# Saving us700069-II-CMLA.sac
# Saving us700069-II-ESK.sac
# Saving us700069-II-KIV.sac
# Saving us700069-II-SACV.sac
# Saving us700069-IU-FURI.sac
# Saving us700069-G-EDA.sac
# Saving us700069-IU-LSZ.sac
# Saving us700069-IU-TSUM.sac
# Saving us700069-II-ASCN.sac
# Saving us700069-G-CRZF.sac
# Saving us700069-II-WRAB.sac
# Saving us700069-G-TRIS.sac
# Saving us700069-IU-CASY.sac
# Saving us700069-II-HOPE.sac
# Saving us700069-G-SPB.sac
# Saving us700069-IU-TRQA.sac
# Saving us700069-G-PEL.sac
# Saving us700069-II-NNA.sac
# Saving us700069-IU-SDV.sac
# Saving us700069-CU-BBGH.sac
# Saving us700069-CU-ANWB.sac
# Saving us700069-IU-DWPF.sac
# Saving us700069-IU-BBSR.sac
# Saving us700069-IU-HRV.sac
# Saving us700069-G-IVI.sac
# Saving us7000132-II-BORG.sac
# Saving us7000132-II-CMLA.sac
# Saving us7000132-II-ESK.sac
# Saving us7000132-II-KIV.sac
# Saving us7000132-II-SACV.sac
# Saving us7000132-IU-FURI.sac
# Saving us7000132-G-EDA.sac
# Saving us7000132-IU-LSZ.sac
# Saving us7000132-IU-TSUM.sac
# Saving us7000132-II-ASCN.sac
# Saving us7000132-G-CRZF.sac
# Saving us7000132-II-WRAB.sac
# Saving us7000132-G-TRIS.sac
# Saving us7000132-IU-CASY.sac
# Saving us7000132-II-HOPE.sac
# Saving us7000132-G-SPB.sac
# Saving us7000132-IU-TRQA.sac
# Saving us7000132-G-PEL.sac
# Saving us7000132-II-NNA.sac
# Saving us7000132-IU-SDV.sac
# Saving us7000132-CU-BBGH.sac
# Saving us7000132-CU-ANWB.sac
# Saving us7000132-IU-DWPF.sac
# Saving us7000132-IU-BBSR.sac
# Saving us7000132-IU-HRV.sac
# Saving us7000132-G-IVI.sac
# Saving us700029-II-BORG.sac
# Saving us700029-II-CMLA.sac
# Saving us700029-II-ESK.sac
# Saving us700029-II-KIV.sac
# Saving us700029-II-SACV.sac
# Saving us700029-IU-FURI.sac
# Saving us700029-G-EDA.sac
# Saving us700029-IU-LSZ.sac
# Saving us700029-IU-TSUM.sac
# Saving us700029-II-ASCN.sac
# Saving us700029-G-CRZF.sac
# Saving us700029-II-WRAB.sac
# Saving us700029-G-TRIS.sac
# Saving us700029-IU-CASY.sac
# Saving us700029-II-HOPE.sac
# Saving us700029-G-SPB.sac
# Saving us700029-IU-TRQA.sac
# Saving us700029-G-PEL.sac
# Saving us700029-II-NNA.sac
# Saving us700029-IU-SDV.sac
# Saving us700029-CU-BBGH.sac
# Saving us700029-CU-ANWB.sac
# Saving us700029-IU-DWPF.sac
# Saving us700029-IU-BBSR.sac
# Saving us700029-IU-HRV.sac
# Saving us700029-G-IVI.sac
# Saving us700081-II-BORG.sac
# Saving us700081-II-CMLA.sac
# Saving us700081-II-ESK.sac
# Saving us700081-II-KIV.sac
# Saving us700081-II-SACV.sac
# Saving us700081-IU-FURI.sac
# Saving us700081-G-EDA.sac
# Saving us700081-IU-LSZ.sac
# Saving us700081-IU-TSUM.sac
# Saving us700081-II-ASCN.sac
# Saving us700081-G-CRZF.sac
# Saving us700081-II-WRAB.sac
# Saving us700081-G-TRIS.sac
# Saving us700081-IU-CASY.sac
# Saving us700081-II-HOPE.sac
# Saving us700081-G-SPB.sac
# Saving us700081-IU-TRQA.sac
# Saving us700081-G-PEL.sac
# Saving us700081-II-NNA.sac
# Saving us700081-IU-SDV.sac
# Saving us700081-CU-BBGH.sac
# Saving us700081-CU-ANWB.sac
# Saving us700081-IU-DWPF.sac
# Saving us700081-IU-BBSR.sac
# Saving us700081-IU-HRV.sac
# Saving us700081-G-IVI.sac
# Saving us700028-II-BORG.sac
# Saving us700028-II-CMLA.sac
# Saving us700028-II-ESK.sac
# Saving us700028-II-KIV.sac
# Saving us700028-II-SACV.sac
# Saving us700028-IU-FURI.sac
# Saving us700028-G-EDA.sac
# Saving us700028-IU-LSZ.sac
# Saving us700028-IU-TSUM.sac
# Saving us700028-II-ASCN.sac
# Saving us700028-G-CRZF.sac
# Saving us700028-II-WRAB.sac
# Saving us700028-G-TRIS.sac
# Saving us700028-IU-CASY.sac
# Saving us700028-II-HOPE.sac
# Saving us700028-G-SPB.sac
# Saving us700028-IU-TRQA.sac
# Saving us700028-G-PEL.sac
# Saving us700028-II-NNA.sac
# Saving us700028-IU-SDV.sac
# Saving us700028-CU-BBGH.sac
# Saving us700028-CU-ANWB.sac
# Saving us700028-IU-DWPF.sac
# Saving us700028-IU-BBSR.sac
# Saving us700028-IU-HRV.sac
# Saving us700028-G-IVI.sac
# Saving us7000116-II-BORG.sac
# Saving us7000116-II-CMLA.sac
# Saving us7000116-II-ESK.sac
# Saving us7000116-II-KIV.sac
# Saving us7000116-II-SACV.sac
# Saving us7000116-IU-FURI.sac
# Saving us7000116-G-EDA.sac
# Saving us7000116-IU-LSZ.sac
# Saving us7000116-IU-TSUM.sac
# Saving us7000116-II-ASCN.sac
# Saving us7000116-G-CRZF.sac
# Saving us7000116-II-WRAB.sac
# Saving us7000116-G-TRIS.sac
# Saving us7000116-IU-CASY.sac
# Saving us7000116-II-HOPE.sac
# Saving us7000116-G-SPB.sac
# Saving us7000116-IU-TRQA.sac
# Saving us7000116-G-PEL.sac
# Saving us7000116-II-NNA.sac
# Saving us7000116-IU-SDV.sac
# Saving us7000116-CU-BBGH.sac
# Saving us7000116-CU-ANWB.sac
# Saving us7000116-IU-DWPF.sac
# Saving us7000116-IU-BBSR.sac
# Saving us7000116-IU-HRV.sac
# Saving us7000116-G-IVI.sac
# Saving us7000114-II-BORG.sac
# Saving us7000114-II-CMLA.sac
# Saving us7000114-II-ESK.sac
# Saving us7000114-II-KIV.sac
# Saving us7000114-II-SACV.sac
# Saving us7000114-IU-FURI.sac
# Saving us7000114-G-EDA.sac
# Saving us7000114-IU-LSZ.sac
# Saving us7000114-IU-TSUM.sac
# Saving us7000114-II-ASCN.sac
# Saving us7000114-G-CRZF.sac
# Saving us7000114-II-WRAB.sac
# Saving us7000114-G-TRIS.sac
# Saving us7000114-IU-CASY.sac
# Saving us7000114-II-HOPE.sac
# Saving us7000114-G-SPB.sac
# Saving us7000114-IU-TRQA.sac
# Saving us7000114-G-PEL.sac
# Saving us7000114-II-NNA.sac
# Saving us7000114-IU-SDV.sac
# Saving us7000114-CU-BBGH.sac
# Saving us7000114-CU-ANWB.sac
# Saving us7000114-IU-DWPF.sac
# Saving us7000114-IU-BBSR.sac
# Saving us7000114-IU-HRV.sac
# Saving us7000114-G-IVI.sac
# Saving us700088-II-BORG.sac
# Saving us700088-II-CMLA.sac
# Saving us700088-II-ESK.sac
# Saving us700088-II-KIV.sac
# Saving us700088-II-SACV.sac
# Saving us700088-IU-FURI.sac
# Saving us700088-G-EDA.sac
# Saving us700088-IU-LSZ.sac
# Saving us700088-IU-TSUM.sac
# Saving us700088-II-ASCN.sac
# Saving us700088-G-CRZF.sac
# Saving us700088-II-WRAB.sac
# Saving us700088-G-TRIS.sac
# Saving us700088-IU-CASY.sac
# Saving us700088-II-HOPE.sac
# Saving us700088-G-SPB.sac
# Saving us700088-IU-TRQA.sac
# Saving us700088-G-PEL.sac
# Saving us700088-II-NNA.sac
# Saving us700088-IU-SDV.sac
# Saving us700088-CU-BBGH.sac
# Saving us700088-CU-ANWB.sac
# Saving us700088-IU-DWPF.sac
# Saving us700088-IU-BBSR.sac
# Saving us700088-IU-HRV.sac
# Saving us700088-G-IVI.sac
# Saving us7000102-II-BORG.sac
# Saving us7000102-II-CMLA.sac
# Saving us7000102-II-ESK.sac
# Saving us7000102-II-KIV.sac
# Saving us7000102-II-SACV.sac
# Saving us7000102-IU-FURI.sac
# Saving us7000102-G-EDA.sac
# Saving us7000102-IU-LSZ.sac
# Saving us7000102-IU-TSUM.sac
# Saving us7000102-II-ASCN.sac
# Saving us7000102-G-CRZF.sac
# Saving us7000102-II-WRAB.sac
# Saving us7000102-G-TRIS.sac
# Saving us7000102-IU-CASY.sac
# Saving us7000102-II-HOPE.sac
# Saving us7000102-G-SPB.sac
# Saving us7000102-IU-TRQA.sac
# Saving us7000102-G-PEL.sac
# Saving us7000102-II-NNA.sac
# Saving us7000102-IU-SDV.sac
# Saving us7000102-CU-BBGH.sac
# Saving us7000102-CU-ANWB.sac
# Saving us7000102-IU-DWPF.sac
# Saving us7000102-IU-BBSR.sac
# Saving us7000102-IU-HRV.sac
# Saving us7000102-G-IVI.sac
# Saving us7000120-II-BORG.sac
# Saving us7000120-II-CMLA.sac
# Saving us7000120-II-ESK.sac
# Saving us7000120-II-KIV.sac
# Saving us7000120-II-SACV.sac
# Saving us7000120-IU-FURI.sac
# Saving us7000120-G-EDA.sac
# Saving us7000120-IU-LSZ.sac
# Saving us7000120-IU-TSUM.sac
# Saving us7000120-II-ASCN.sac
# Saving us7000120-G-CRZF.sac
# Saving us7000120-II-WRAB.sac
# Saving us7000120-G-TRIS.sac
# Saving us7000120-IU-CASY.sac
# Saving us7000120-II-HOPE.sac
# Saving us7000120-G-SPB.sac
# Saving us7000120-IU-TRQA.sac
# Saving us7000120-G-PEL.sac
# Saving us7000120-II-NNA.sac
# Saving us7000120-IU-SDV.sac
# Saving us7000120-CU-BBGH.sac
# Saving us7000120-CU-ANWB.sac
# Saving us7000120-IU-DWPF.sac
# Saving us7000120-IU-BBSR.sac
# Saving us7000120-IU-HRV.sac
# Saving us7000120-G-IVI.sac
# Saving us7000119-II-BORG.sac
# Saving us7000119-II-CMLA.sac
# Saving us7000119-II-ESK.sac
# Saving us7000119-II-KIV.sac
# Saving us7000119-II-SACV.sac
# Saving us7000119-IU-FURI.sac
# Saving us7000119-G-EDA.sac
# Saving us7000119-IU-LSZ.sac
# Saving us7000119-IU-TSUM.sac
# Saving us7000119-II-ASCN.sac
# Saving us7000119-G-CRZF.sac
# Saving us7000119-II-WRAB.sac
# Saving us7000119-G-TRIS.sac
# Saving us7000119-IU-CASY.sac
# Saving us7000119-II-HOPE.sac
# Saving us7000119-G-SPB.sac
# Saving us7000119-IU-TRQA.sac
# Saving us7000119-G-PEL.sac
# Saving us7000119-II-NNA.sac
# Saving us7000119-IU-SDV.sac
# Saving us7000119-CU-BBGH.sac
# Saving us7000119-CU-ANWB.sac
# Saving us7000119-IU-DWPF.sac
# Saving us7000119-IU-BBSR.sac
# Saving us7000119-IU-HRV.sac
# Saving us7000119-G-IVI.sac
# Saving us700095-II-BORG.sac
# Saving us700095-II-CMLA.sac
# Saving us700095-II-ESK.sac
# Saving us700095-II-KIV.sac
# Saving us700095-II-SACV.sac
# Saving us700095-IU-FURI.sac
# Saving us700095-G-EDA.sac
# Saving us700095-IU-LSZ.sac
# Saving us700095-IU-TSUM.sac
# Saving us700095-II-ASCN.sac
# Saving us700095-G-CRZF.sac
# Saving us700095-II-WRAB.sac
# Saving us700095-G-TRIS.sac
# Saving us700095-IU-CASY.sac
# Saving us700095-II-HOPE.sac
# Saving us700095-G-SPB.sac
# Saving us700095-IU-TRQA.sac
# Saving us700095-G-PEL.sac
# Saving us700095-II-NNA.sac
# Saving us700095-IU-SDV.sac
# Saving us700095-CU-BBGH.sac
# Saving us700095-CU-ANWB.sac
# Saving us700095-IU-DWPF.sac
# Saving us700095-IU-BBSR.sac
# Saving us700095-IU-HRV.sac
# Saving us700095-G-IVI.sac
# Saving us700047-II-BORG.sac
# Saving us700047-II-CMLA.sac
# Saving us700047-II-ESK.sac
# Saving us700047-II-KIV.sac
# Saving us700047-II-SACV.sac
# Saving us700047-IU-FURI.sac
# Saving us700047-G-EDA.sac
# Saving us700047-IU-LSZ.sac
# Saving us700047-IU-TSUM.sac
# Saving us700047-II-ASCN.sac
# Saving us700047-G-CRZF.sac
# Saving us700047-II-WRAB.sac
# Saving us700047-G-TRIS.sac
# Saving us700047-IU-CASY.sac
# Saving us700047-II-HOPE.sac
# Saving us700047-G-SPB.sac
# Saving us700047-IU-TRQA.sac
# Saving us700047-G-PEL.sac
# Saving us700047-II-NNA.sac
# Saving us700047-IU-SDV.sac
# Saving us700047-CU-BBGH.sac
# Saving us700047-CU-ANWB.sac
# Saving us700047-IU-DWPF.sac
# Saving us700047-IU-BBSR.sac
# Saving us700047-IU-HRV.sac
# Saving us700047-G-IVI.sac
# Saving us700067-II-BORG.sac
# Saving us700067-II-CMLA.sac
# Saving us700067-II-ESK.sac
# Saving us700067-II-KIV.sac
# Saving us700067-II-SACV.sac
# Saving us700067-IU-FURI.sac
# Saving us700067-G-EDA.sac
# Saving us700067-IU-LSZ.sac
# Saving us700067-IU-TSUM.sac
# Saving us700067-II-ASCN.sac
# Saving us700067-G-CRZF.sac
# Saving us700067-II-WRAB.sac
# Saving us700067-G-TRIS.sac
# Saving us700067-IU-CASY.sac
# Saving us700067-II-HOPE.sac
# Saving us700067-G-SPB.sac
# Saving us700067-IU-TRQA.sac
# Saving us700067-G-PEL.sac
# Saving us700067-II-NNA.sac
# Saving us700067-IU-SDV.sac
# Saving us700067-CU-BBGH.sac
# Saving us700067-CU-ANWB.sac
# Saving us700067-IU-DWPF.sac
# Saving us700067-IU-BBSR.sac
# Saving us700067-IU-HRV.sac
# Saving us700067-G-IVI.sac
# Saving us7000123-II-BORG.sac
# Saving us7000123-II-CMLA.sac
# Saving us7000123-II-ESK.sac
# Saving us7000123-II-KIV.sac
# Saving us7000123-II-SACV.sac
# Saving us7000123-IU-FURI.sac
# Saving us7000123-G-EDA.sac
# Saving us7000123-IU-LSZ.sac
# Saving us7000123-IU-TSUM.sac
# Saving us7000123-II-ASCN.sac
# Saving us7000123-G-CRZF.sac
# Saving us7000123-II-WRAB.sac
# Saving us7000123-G-TRIS.sac
# Saving us7000123-IU-CASY.sac
# Saving us7000123-II-HOPE.sac
# Saving us7000123-G-SPB.sac
# Saving us7000123-IU-TRQA.sac
# Saving us7000123-G-PEL.sac
# Saving us7000123-II-NNA.sac
# Saving us7000123-IU-SDV.sac
# Saving us7000123-CU-BBGH.sac
# Saving us7000123-CU-ANWB.sac
# Saving us7000123-IU-DWPF.sac
# Saving us7000123-IU-BBSR.sac
# Saving us7000123-IU-HRV.sac
# Saving us7000123-G-IVI.sac
# Saving us7000111-II-BORG.sac
# Saving us7000111-II-CMLA.sac
# Saving us7000111-II-ESK.sac
# Saving us7000111-II-KIV.sac
# Saving us7000111-II-SACV.sac
# Saving us7000111-IU-FURI.sac
# Saving us7000111-G-EDA.sac
# Saving us7000111-IU-LSZ.sac
# Saving us7000111-IU-TSUM.sac
# Saving us7000111-II-ASCN.sac
# Saving us7000111-G-CRZF.sac
# Saving us7000111-II-WRAB.sac
# Saving us7000111-G-TRIS.sac
# Saving us7000111-IU-CASY.sac
# Saving us7000111-II-HOPE.sac
# Saving us7000111-G-SPB.sac
# Saving us7000111-IU-TRQA.sac
# Saving us7000111-G-PEL.sac
# Saving us7000111-II-NNA.sac
# Saving us7000111-IU-SDV.sac
# Saving us7000111-CU-BBGH.sac
# Saving us7000111-CU-ANWB.sac
# Saving us7000111-IU-DWPF.sac
# Saving us7000111-IU-BBSR.sac
# Saving us7000111-IU-HRV.sac
# Saving us7000111-G-IVI.sac
# Saving us700057-II-BORG.sac
# Saving us700057-II-CMLA.sac
# Saving us700057-II-ESK.sac
# Saving us700057-II-KIV.sac
# Saving us700057-II-SACV.sac
# Saving us700057-IU-FURI.sac
# Saving us700057-G-EDA.sac
# Saving us700057-IU-LSZ.sac
# Saving us700057-IU-TSUM.sac
# Saving us700057-II-ASCN.sac
# Saving us700057-G-CRZF.sac
# Saving us700057-II-WRAB.sac
# Saving us700057-G-TRIS.sac
# Saving us700057-IU-CASY.sac
# Saving us700057-II-HOPE.sac
# Saving us700057-G-SPB.sac
# Saving us700057-IU-TRQA.sac
# Saving us700057-G-PEL.sac
# Saving us700057-II-NNA.sac
# Saving us700057-IU-SDV.sac
# Saving us700057-CU-BBGH.sac
# Saving us700057-CU-ANWB.sac
# Saving us700057-IU-DWPF.sac
# Saving us700057-IU-BBSR.sac
# Saving us700057-IU-HRV.sac
# Saving us700057-G-IVI.sac
# Saving us700075-II-BORG.sac
# Saving us700075-II-CMLA.sac
# Saving us700075-II-ESK.sac
# Saving us700075-II-KIV.sac
# Saving us700075-II-SACV.sac
# Saving us700075-IU-FURI.sac
# Saving us700075-G-EDA.sac
# Saving us700075-IU-LSZ.sac
# Saving us700075-IU-TSUM.sac
# Saving us700075-II-ASCN.sac
# Saving us700075-G-CRZF.sac
# Saving us700075-II-WRAB.sac
# Saving us700075-G-TRIS.sac
# Saving us700075-IU-CASY.sac
# Saving us700075-II-HOPE.sac
# Saving us700075-G-SPB.sac
# Saving us700075-IU-TRQA.sac
# Saving us700075-G-PEL.sac
# Saving us700075-II-NNA.sac
# Saving us700075-IU-SDV.sac
# Saving us700075-CU-BBGH.sac
# Saving us700075-CU-ANWB.sac
# Saving us700075-IU-DWPF.sac
# Saving us700075-IU-BBSR.sac
# Saving us700075-IU-HRV.sac
# Saving us700075-G-IVI.sac
# Saving us700037-II-BORG.sac
# Saving us700037-II-CMLA.sac
# Saving us700037-II-ESK.sac
# Saving us700037-II-KIV.sac
# Saving us700037-II-SACV.sac
# Saving us700037-IU-FURI.sac
# Saving us700037-G-EDA.sac
# Saving us700037-IU-LSZ.sac
# Saving us700037-IU-TSUM.sac
# Saving us700037-II-ASCN.sac
# Saving us700037-G-CRZF.sac
# Saving us700037-II-WRAB.sac
# Saving us700037-G-TRIS.sac
# Saving us700037-IU-CASY.sac
# Saving us700037-II-HOPE.sac
# Saving us700037-G-SPB.sac
# Saving us700037-IU-TRQA.sac
# Saving us700037-G-PEL.sac
# Saving us700037-II-NNA.sac
# Saving us700037-IU-SDV.sac
# Saving us700037-CU-BBGH.sac
# Saving us700037-CU-ANWB.sac
# Saving us700037-IU-DWPF.sac
# Saving us700037-IU-BBSR.sac
# Saving us700037-IU-HRV.sac
# Saving us700037-G-IVI.sac
# Saving us700094-II-BORG.sac
# Saving us700094-II-CMLA.sac
# Saving us700094-II-ESK.sac
# Saving us700094-II-KIV.sac
# Saving us700094-II-SACV.sac
# Saving us700094-IU-FURI.sac
# Saving us700094-G-EDA.sac
# Saving us700094-IU-LSZ.sac
# Saving us700094-IU-TSUM.sac
# Saving us700094-II-ASCN.sac
# Saving us700094-G-CRZF.sac
# Saving us700094-II-WRAB.sac
# Saving us700094-G-TRIS.sac
# Saving us700094-IU-CASY.sac
# Saving us700094-II-HOPE.sac
# Saving us700094-G-SPB.sac
# Saving us700094-IU-TRQA.sac
# Saving us700094-G-PEL.sac
# Saving us700094-II-NNA.sac
# Saving us700094-IU-SDV.sac
# Saving us700094-CU-BBGH.sac
# Saving us700094-CU-ANWB.sac
# Saving us700094-IU-DWPF.sac
# Saving us700094-IU-BBSR.sac
# Saving us700094-IU-HRV.sac
# Saving us700094-G-IVI.sac
# Saving us700099-II-BORG.sac
# Saving us700099-II-CMLA.sac
# Saving us700099-II-ESK.sac
# Saving us700099-II-KIV.sac
# Saving us700099-II-SACV.sac
# Saving us700099-IU-FURI.sac
# Saving us700099-G-EDA.sac
# Saving us700099-IU-LSZ.sac
# Saving us700099-IU-TSUM.sac
# Saving us700099-II-ASCN.sac
# Saving us700099-G-CRZF.sac
# Saving us700099-II-WRAB.sac
# Saving us700099-G-TRIS.sac
# Saving us700099-IU-CASY.sac
# Saving us700099-II-HOPE.sac
# Saving us700099-G-SPB.sac
# Saving us700099-IU-TRQA.sac
# Saving us700099-G-PEL.sac
# Saving us700099-II-NNA.sac
# Saving us700099-IU-SDV.sac
# Saving us700099-CU-BBGH.sac
# Saving us700099-CU-ANWB.sac
# Saving us700099-IU-DWPF.sac
# Saving us700099-IU-BBSR.sac
# Saving us700099-IU-HRV.sac
# Saving us700099-G-IVI.sac
# Saving us700076-II-BORG.sac
# Saving us700076-II-CMLA.sac
# Saving us700076-II-ESK.sac
# Saving us700076-II-KIV.sac
# Saving us700076-II-SACV.sac
# Saving us700076-IU-FURI.sac
# Saving us700076-G-EDA.sac
# Saving us700076-IU-LSZ.sac
# Saving us700076-IU-TSUM.sac
# Saving us700076-II-ASCN.sac
# Saving us700076-G-CRZF.sac
# Saving us700076-II-WRAB.sac
# Saving us700076-G-TRIS.sac
# Saving us700076-IU-CASY.sac
# Saving us700076-II-HOPE.sac
# Saving us700076-G-SPB.sac
# Saving us700076-IU-TRQA.sac
# Saving us700076-G-PEL.sac
# Saving us700076-II-NNA.sac
# Saving us700076-IU-SDV.sac
# Saving us700076-CU-BBGH.sac
# Saving us700076-CU-ANWB.sac
# Saving us700076-IU-DWPF.sac
# Saving us700076-IU-BBSR.sac
# Saving us700076-IU-HRV.sac
# Saving us700076-G-IVI.sac
# Saving us700061-II-BORG.sac
# Saving us700061-II-CMLA.sac
# Saving us700061-II-ESK.sac
# Saving us700061-II-KIV.sac
# Saving us700061-II-SACV.sac
# Saving us700061-IU-FURI.sac
# Saving us700061-G-EDA.sac
# Saving us700061-IU-LSZ.sac
# Saving us700061-IU-TSUM.sac
# Saving us700061-II-ASCN.sac
# Saving us700061-G-CRZF.sac
# Saving us700061-II-WRAB.sac
# Saving us700061-G-TRIS.sac
# Saving us700061-IU-CASY.sac
# Saving us700061-II-HOPE.sac
# Saving us700061-G-SPB.sac
# Saving us700061-IU-TRQA.sac
# Saving us700061-G-PEL.sac
# Saving us700061-II-NNA.sac
# Saving us700061-IU-SDV.sac
# Saving us700061-CU-BBGH.sac
# Saving us700061-CU-ANWB.sac
# Saving us700061-IU-DWPF.sac
# Saving us700061-IU-BBSR.sac
# Saving us700061-IU-HRV.sac
# Saving us700061-G-IVI.sac
# Saving us700082-II-BORG.sac
# Saving us700082-II-CMLA.sac
# Saving us700082-II-ESK.sac
# Saving us700082-II-KIV.sac
# Saving us700082-II-SACV.sac
# Saving us700082-IU-FURI.sac
# Saving us700082-G-EDA.sac
# Saving us700082-IU-LSZ.sac
# Saving us700082-IU-TSUM.sac
# Saving us700082-II-ASCN.sac
# Saving us700082-G-CRZF.sac
# Saving us700082-II-WRAB.sac
# Saving us700082-G-TRIS.sac
# Saving us700082-IU-CASY.sac
# Saving us700082-II-HOPE.sac
# Saving us700082-G-SPB.sac
# Saving us700082-IU-TRQA.sac
# Saving us700082-G-PEL.sac
# Saving us700082-II-NNA.sac
# Saving us700082-IU-SDV.sac
# Saving us700082-CU-BBGH.sac
# Saving us700082-CU-ANWB.sac
# Saving us700082-IU-DWPF.sac
# Saving us700082-IU-BBSR.sac
# Saving us700082-IU-HRV.sac
# Saving us700082-G-IVI.sac
# ...
# Saving us700038-CU-BBGH.sac
# Saving us700038-CU-ANWB.sac
# Saving us700038-IU-DWPF.sac
# Saving us700038-IU-BBSR.sac
# Saving us700038-IU-HRV.sac
# Saving us700038-G-IVI.sac
# Saving us700073-II-BORG.sac
# Saving us700073-II-CMLA.sac
# Saving us700073-II-ESK.sac
# Saving us700073-II-KIV.sac
# Saving us700073-II-SACV.sac
# Saving us700073-IU-FURI.sac
# Saving us700073-G-EDA.sac
# Saving us700073-IU-LSZ.sac
# Saving us700073-IU-TSUM.sac
# Saving us700073-II-ASCN.sac
# Saving us700073-G-CRZF.sac
# Saving us700073-II-WRAB.sac
# Saving us700073-G-TRIS.sac
# Saving us700073-IU-CASY.sac
# Saving us700073-II-HOPE.sac
# Saving us700073-G-SPB.sac
# Saving us700073-IU-TRQA.sac
# Saving us700073-G-PEL.sac
# Saving us700073-II-NNA.sac
# Saving us700073-IU-SDV.sac
# Saving us700073-CU-BBGH.sac
# Saving us700073-CU-ANWB.sac
# Saving us700073-IU-DWPF.sac
# Saving us700073-IU-BBSR.sac
# Saving us700073-IU-HRV.sac
# Saving us700073-G-IVI.sac
# Saving us7000108-II-BORG.sac
# Saving us7000108-II-CMLA.sac
# Saving us7000108-II-ESK.sac
# Saving us7000108-II-KIV.sac
# Saving us7000108-II-SACV.sac
# Saving us7000108-IU-FURI.sac
# Saving us7000108-G-EDA.sac
# Saving us7000108-IU-LSZ.sac
# Saving us7000108-IU-TSUM.sac
# Saving us7000108-II-ASCN.sac
# Saving us7000108-G-CRZF.sac
# Saving us7000108-II-WRAB.sac
# Saving us7000108-G-TRIS.sac
# Saving us7000108-IU-CASY.sac
# Saving us7000108-II-HOPE.sac
# Saving us7000108-G-SPB.sac
# Saving us7000108-IU-TRQA.sac
# Saving us7000108-G-PEL.sac
# Saving us7000108-II-NNA.sac
# Saving us7000108-IU-SDV.sac
# Saving us7000108-CU-BBGH.sac
# Saving us7000108-CU-ANWB.sac
# Saving us7000108-IU-DWPF.sac
# Saving us7000108-IU-BBSR.sac
# Saving us7000108-IU-HRV.sac
# Saving us7000108-G-IVI.sac
# Saving us7000129-II-BORG.sac
# Saving us7000129-II-CMLA.sac
# Saving us7000129-II-ESK.sac
# Saving us7000129-II-KIV.sac
# Saving us7000129-II-SACV.sac
# Saving us7000129-IU-FURI.sac
# Saving us7000129-G-EDA.sac
# Saving us7000129-IU-LSZ.sac
# Saving us7000129-IU-TSUM.sac
# Saving us7000129-II-ASCN.sac
# Saving us7000129-G-CRZF.sac
# Saving us7000129-II-WRAB.sac
# Saving us7000129-G-TRIS.sac
# Saving us7000129-IU-CASY.sac
# Saving us7000129-II-HOPE.sac
# Saving us7000129-G-SPB.sac
# Saving us7000129-IU-TRQA.sac
# Saving us7000129-G-PEL.sac
# Saving us7000129-II-NNA.sac
# Saving us7000129-IU-SDV.sac
# Saving us7000129-CU-BBGH.sac
# Saving us7000129-CU-ANWB.sac
# Saving us7000129-IU-DWPF.sac
# Saving us7000129-IU-BBSR.sac
# Saving us7000129-IU-HRV.sac
# Saving us7000129-G-IVI.sac
# Saving us700059-II-BORG.sac
# Saving us700059-II-CMLA.sac
# Saving us700059-II-ESK.sac
# Saving us700059-II-KIV.sac
# Saving us700059-II-SACV.sac
# Saving us700059-IU-FURI.sac
# Saving us700059-G-EDA.sac
# Saving us700059-IU-LSZ.sac
# Saving us700059-IU-TSUM.sac
# Saving us700059-II-ASCN.sac
# Saving us700059-G-CRZF.sac
# Saving us700059-II-WRAB.sac
# Saving us700059-G-TRIS.sac
# Saving us700059-IU-CASY.sac
# Saving us700059-II-HOPE.sac
# Saving us700059-G-SPB.sac
# Saving us700059-IU-TRQA.sac
# Saving us700059-G-PEL.sac
# Saving us700059-II-NNA.sac
# Saving us700059-IU-SDV.sac
# Saving us700059-CU-BBGH.sac
# Saving us700059-CU-ANWB.sac
# Saving us700059-IU-DWPF.sac
# Saving us700059-IU-BBSR.sac
# Saving us700059-IU-HRV.sac
# Saving us700059-G-IVI.sac
# Saving us700068-II-BORG.sac
# Saving us700068-II-CMLA.sac
# Saving us700068-II-ESK.sac
# Saving us700068-II-KIV.sac
# Saving us700068-II-SACV.sac
# Saving us700068-IU-FURI.sac
# Saving us700068-G-EDA.sac
# Saving us700068-IU-LSZ.sac
# Saving us700068-IU-TSUM.sac
# Saving us700068-II-ASCN.sac
# Saving us700068-G-CRZF.sac
# Saving us700068-II-WRAB.sac
# Saving us700068-G-TRIS.sac
# Saving us700068-IU-CASY.sac
# Saving us700068-II-HOPE.sac
# Saving us700068-G-SPB.sac
# Saving us700068-IU-TRQA.sac
# Saving us700068-G-PEL.sac
# Saving us700068-II-NNA.sac
# Saving us700068-IU-SDV.sac
# Saving us700068-CU-BBGH.sac
# Saving us700068-CU-ANWB.sac
# Saving us700068-IU-DWPF.sac
# Saving us700068-IU-BBSR.sac
# Saving us700068-IU-HRV.sac
# Saving us700068-G-IVI.sac
# Saving us7000100-II-BORG.sac
# Saving us7000100-II-CMLA.sac
# Saving us7000100-II-ESK.sac
# Saving us7000100-II-KIV.sac
# Saving us7000100-II-SACV.sac
# Saving us7000100-IU-FURI.sac
# Saving us7000100-G-EDA.sac
# Saving us7000100-IU-LSZ.sac
# Saving us7000100-IU-TSUM.sac
# Saving us7000100-II-ASCN.sac
# Saving us7000100-G-CRZF.sac
# Saving us7000100-II-WRAB.sac
# Saving us7000100-G-TRIS.sac
# Saving us7000100-IU-CASY.sac
# Saving us7000100-II-HOPE.sac
# Saving us7000100-G-SPB.sac
# Saving us7000100-IU-TRQA.sac
# Saving us7000100-G-PEL.sac
# Saving us7000100-II-NNA.sac
# Saving us7000100-IU-SDV.sac
# Saving us7000100-CU-BBGH.sac
# Saving us7000100-CU-ANWB.sac
# Saving us7000100-IU-DWPF.sac
# Saving us7000100-IU-BBSR.sac
# Saving us7000100-IU-HRV.sac
# Saving us7000100-G-IVI.sac
# Saving us700035-II-BORG.sac
# Saving us700035-II-CMLA.sac
# Saving us700035-II-ESK.sac
# Saving us700035-II-KIV.sac
# Saving us700035-II-SACV.sac
# Saving us700035-IU-FURI.sac
# Saving us700035-G-EDA.sac
# Saving us700035-IU-LSZ.sac
# Saving us700035-IU-TSUM.sac
# Saving us700035-II-ASCN.sac
# Saving us700035-G-CRZF.sac
# Saving us700035-II-WRAB.sac
# Saving us700035-G-TRIS.sac
# Saving us700035-IU-CASY.sac
# Saving us700035-II-HOPE.sac
# Saving us700035-G-SPB.sac
# Saving us700035-IU-TRQA.sac
# Saving us700035-G-PEL.sac
# Saving us700035-II-NNA.sac
# Saving us700035-IU-SDV.sac
# Saving us700035-CU-BBGH.sac
# Saving us700035-CU-ANWB.sac
# Saving us700035-IU-DWPF.sac
# Saving us700035-IU-BBSR.sac
# Saving us700035-IU-HRV.sac
# Saving us700035-G-IVI.sac
# Saving us700087-II-BORG.sac
# Saving us700087-II-CMLA.sac
# Saving us700087-II-ESK.sac
# Saving us700087-II-KIV.sac
# Saving us700087-II-SACV.sac
# Saving us700087-IU-FURI.sac
# Saving us700087-G-EDA.sac
# Saving us700087-IU-LSZ.sac
# Saving us700087-IU-TSUM.sac
# Saving us700087-II-ASCN.sac
# Saving us700087-G-CRZF.sac
# Saving us700087-II-WRAB.sac
# Saving us700087-G-TRIS.sac
# Saving us700087-IU-CASY.sac
# Saving us700087-II-HOPE.sac
# Saving us700087-G-SPB.sac
# Saving us700087-IU-TRQA.sac
# Saving us700087-G-PEL.sac
# Saving us700087-II-NNA.sac
# Saving us700087-IU-SDV.sac
# Saving us700087-CU-BBGH.sac
# Saving us700087-CU-ANWB.sac
# Saving us700087-IU-DWPF.sac
# Saving us700087-IU-BBSR.sac
# Saving us700087-IU-HRV.sac
# Saving us700087-G-IVI.sac
# Saving us7000113-II-BORG.sac
# Saving us7000113-II-CMLA.sac
# Saving us7000113-II-ESK.sac
# Saving us7000113-II-KIV.sac
# Saving us7000113-II-SACV.sac
# Saving us7000113-IU-FURI.sac
# Saving us7000113-G-EDA.sac
# Saving us7000113-IU-LSZ.sac
# Saving us7000113-IU-TSUM.sac
# Saving us7000113-II-ASCN.sac
# Saving us7000113-G-CRZF.sac
# Saving us7000113-II-WRAB.sac
# Saving us7000113-G-TRIS.sac
# Saving us7000113-IU-CASY.sac
# Saving us7000113-II-HOPE.sac
# Saving us7000113-G-SPB.sac
# Saving us7000113-IU-TRQA.sac
# Saving us7000113-G-PEL.sac
# Saving us7000113-II-NNA.sac
# Saving us7000113-IU-SDV.sac
# Saving us7000113-CU-BBGH.sac
# Saving us7000113-CU-ANWB.sac
# Saving us7000113-IU-DWPF.sac
# Saving us7000113-IU-BBSR.sac
# Saving us7000113-IU-HRV.sac
# Saving us7000113-G-IVI.sac
# Saving us7000115-II-BORG.sac
# Saving us7000115-II-CMLA.sac
# Saving us7000115-II-ESK.sac
# Saving us7000115-II-KIV.sac
# Saving us7000115-II-SACV.sac
# Saving us7000115-IU-FURI.sac
# Saving us7000115-G-EDA.sac
# Saving us7000115-IU-LSZ.sac
# Saving us7000115-IU-TSUM.sac
# Saving us7000115-II-ASCN.sac
# Saving us7000115-G-CRZF.sac
# Saving us7000115-II-WRAB.sac
# Saving us7000115-G-TRIS.sac
# Saving us7000115-IU-CASY.sac
# Saving us7000115-II-HOPE.sac
# Saving us7000115-G-SPB.sac
# Saving us7000115-IU-TRQA.sac
# Saving us7000115-G-PEL.sac
# Saving us7000115-II-NNA.sac
# Saving us7000115-IU-SDV.sac
# Saving us7000115-CU-BBGH.sac
# Saving us7000115-CU-ANWB.sac
# Saving us7000115-IU-DWPF.sac
# Saving us7000115-IU-BBSR.sac
# Saving us7000115-IU-HRV.sac
# Saving us7000115-G-IVI.sac
# Saving us700026-II-BORG.sac
# Saving us700026-II-CMLA.sac
# Saving us700026-II-ESK.sac
# Saving us700026-II-KIV.sac
# Saving us700026-II-SACV.sac
# Saving us700026-IU-FURI.sac
# Saving us700026-G-EDA.sac
# Saving us700026-IU-LSZ.sac
# Saving us700026-IU-TSUM.sac
# Saving us700026-II-ASCN.sac
# Saving us700026-G-CRZF.sac
# Saving us700026-II-WRAB.sac
# Saving us700026-G-TRIS.sac
# Saving us700026-IU-CASY.sac
# Saving us700026-II-HOPE.sac
# Saving us700026-G-SPB.sac
# Saving us700026-IU-TRQA.sac
# Saving us700026-G-PEL.sac
# Saving us700026-II-NNA.sac
# Saving us700026-IU-SDV.sac
# Saving us700026-CU-BBGH.sac
# Saving us700026-CU-ANWB.sac
# Saving us700026-IU-DWPF.sac
# Saving us700026-IU-BBSR.sac
# Saving us700026-IU-HRV.sac
# Saving us700026-G-IVI.sac
# Saving us700093-II-BORG.sac
# Saving us700093-II-CMLA.sac
# Saving us700093-II-ESK.sac
# Saving us700093-II-KIV.sac
# Saving us700093-II-SACV.sac
# Saving us700093-IU-FURI.sac
# Saving us700093-G-EDA.sac
# Saving us700093-IU-LSZ.sac
# Saving us700093-IU-TSUM.sac
# Saving us700093-II-ASCN.sac
# Saving us700093-G-CRZF.sac
# Saving us700093-II-WRAB.sac
# Saving us700093-G-TRIS.sac
# Saving us700093-IU-CASY.sac
# Saving us700093-II-HOPE.sac
# Saving us700093-G-SPB.sac
# Saving us700093-IU-TRQA.sac
# Saving us700093-G-PEL.sac
# Saving us700093-II-NNA.sac
# Saving us700093-IU-SDV.sac
# Saving us700093-CU-BBGH.sac
# Saving us700093-CU-ANWB.sac
# Saving us700093-IU-DWPF.sac
# Saving us700093-IU-BBSR.sac
# Saving us700093-IU-HRV.sac
# Saving us700093-G-IVI.sac
# Saving us700060-II-BORG.sac
# Saving us700060-II-CMLA.sac
# Saving us700060-II-ESK.sac
# Saving us700060-II-KIV.sac
# Saving us700060-II-SACV.sac
# Saving us700060-IU-FURI.sac
# Saving us700060-G-EDA.sac
# Saving us700060-IU-LSZ.sac
# Saving us700060-IU-TSUM.sac
# Saving us700060-II-ASCN.sac
# Saving us700060-G-CRZF.sac
# Saving us700060-II-WRAB.sac
# Saving us700060-G-TRIS.sac
# Saving us700060-IU-CASY.sac
# Saving us700060-II-HOPE.sac
# Saving us700060-G-SPB.sac
# Saving us700060-IU-TRQA.sac
# Saving us700060-G-PEL.sac
# Saving us700060-II-NNA.sac
# Saving us700060-IU-SDV.sac
# Saving us700060-CU-BBGH.sac
# Saving us700060-CU-ANWB.sac
# Saving us700060-IU-DWPF.sac
# Saving us700060-IU-BBSR.sac
# Saving us700060-IU-HRV.sac
# Saving us700060-G-IVI.sac
# Saving us7000126-II-BORG.sac
# Saving us7000126-II-CMLA.sac
# Saving us7000126-II-ESK.sac
# Saving us7000126-II-KIV.sac
# Saving us7000126-II-SACV.sac
# Saving us7000126-IU-FURI.sac
# Saving us7000126-G-EDA.sac
# Saving us7000126-IU-LSZ.sac
# Saving us7000126-IU-TSUM.sac
# Saving us7000126-II-ASCN.sac
# Saving us7000126-G-CRZF.sac
# Saving us7000126-II-WRAB.sac
# Saving us7000126-G-TRIS.sac
# Saving us7000126-IU-CASY.sac
# Saving us7000126-II-HOPE.sac
# Saving us7000126-G-SPB.sac
# Saving us7000126-IU-TRQA.sac
# Saving us7000126-G-PEL.sac
# Saving us7000126-II-NNA.sac
# Saving us7000126-IU-SDV.sac
# Saving us7000126-CU-BBGH.sac
# Saving us7000126-CU-ANWB.sac
# Saving us7000126-IU-DWPF.sac
# Saving us7000126-IU-BBSR.sac
# Saving us7000126-IU-HRV.sac
# Saving us7000126-G-IVI.sac
# Saving us700025-II-BORG.sac
# Saving us700025-II-CMLA.sac
# Saving us700025-II-ESK.sac
# Saving us700025-II-KIV.sac
# Saving us700025-II-SACV.sac
# Saving us700025-IU-FURI.sac
# Saving us700025-G-EDA.sac
# Saving us700025-IU-LSZ.sac
# Saving us700025-IU-TSUM.sac
# Saving us700025-II-ASCN.sac
# Saving us700025-G-CRZF.sac
# Saving us700025-II-WRAB.sac
# Saving us700025-G-TRIS.sac
# Saving us700025-IU-CASY.sac
# Saving us700025-II-HOPE.sac
# Saving us700025-G-SPB.sac
# Saving us700025-IU-TRQA.sac
# Saving us700025-G-PEL.sac
# Saving us700025-II-NNA.sac
# Saving us700025-IU-SDV.sac
# Saving us700025-CU-BBGH.sac
# Saving us700025-CU-ANWB.sac
# Saving us700025-IU-DWPF.sac
# Saving us700025-IU-BBSR.sac
# Saving us700025-IU-HRV.sac
# Saving us700025-G-IVI.sac
# Saving us700071-II-BORG.sac
# Saving us700071-II-CMLA.sac
# Saving us700071-II-ESK.sac
# Saving us700071-II-KIV.sac
# Saving us700071-II-SACV.sac
# Saving us700071-IU-FURI.sac
# Saving us700071-G-EDA.sac
# Saving us700071-IU-LSZ.sac
# Saving us700071-IU-TSUM.sac
# Saving us700071-II-ASCN.sac
# Saving us700071-G-CRZF.sac
# Saving us700071-II-WRAB.sac
# Saving us700071-G-TRIS.sac
# Saving us700071-IU-CASY.sac
# Saving us700071-II-HOPE.sac
# Saving us700071-G-SPB.sac
# Saving us700071-IU-TRQA.sac
# Saving us700071-G-PEL.sac
# Saving us700071-II-NNA.sac
# Saving us700071-IU-SDV.sac
# Saving us700071-CU-BBGH.sac
# Saving us700071-CU-ANWB.sac
# Saving us700071-IU-DWPF.sac
# Saving us700071-IU-BBSR.sac
# Saving us700071-IU-HRV.sac
# Saving us700071-G-IVI.sac
# Saving us700033-II-BORG.sac
# Saving us700033-II-CMLA.sac
# Saving us700033-II-ESK.sac
# Saving us700033-II-KIV.sac
# Saving us700033-II-SACV.sac
# Saving us700033-IU-FURI.sac
# Saving us700033-G-EDA.sac
# Saving us700033-IU-LSZ.sac
# Saving us700033-IU-TSUM.sac
# Saving us700033-II-ASCN.sac
# Saving us700033-G-CRZF.sac
# Saving us700033-II-WRAB.sac
# Saving us700033-G-TRIS.sac
# Saving us700033-IU-CASY.sac
# Saving us700033-II-HOPE.sac
# Saving us700033-G-SPB.sac
# Saving us700033-IU-TRQA.sac
# Saving us700033-G-PEL.sac
# Saving us700033-II-NNA.sac
# Saving us700033-IU-SDV.sac
# Saving us700033-CU-BBGH.sac
# Saving us700033-CU-ANWB.sac
# Saving us700033-IU-DWPF.sac
# Saving us700033-IU-BBSR.sac
# Saving us700033-IU-HRV.sac
# Saving us700033-G-IVI.sac
# Saving us700086-II-BORG.sac
# Saving us700086-II-CMLA.sac
# Saving us700086-II-ESK.sac
# Saving us700086-II-KIV.sac
# Saving us700086-II-SACV.sac
# Saving us700086-IU-FURI.sac
# Saving us700086-G-EDA.sac
# Saving us700086-IU-LSZ.sac
# Saving us700086-IU-TSUM.sac
# Saving us700086-II-ASCN.sac
# Saving us700086-G-CRZF.sac
# Saving us700086-II-WRAB.sac
# Saving us700086-G-TRIS.sac
# Saving us700086-IU-CASY.sac
# Saving us700086-II-HOPE.sac
# Saving us700086-G-SPB.sac
# Saving us700086-IU-TRQA.sac
# Saving us700086-G-PEL.sac
# Saving us700086-II-NNA.sac
# Saving us700086-IU-SDV.sac
# Saving us700086-CU-BBGH.sac
# Saving us700086-CU-ANWB.sac
# Saving us700086-IU-DWPF.sac
# Saving us700086-IU-BBSR.sac
# Saving us700086-IU-HRV.sac
# Saving us700086-G-IVI.sac
# Saving us700063-II-BORG.sac
# Saving us700063-II-CMLA.sac
# Saving us700063-II-ESK.sac
# Saving us700063-II-KIV.sac
# Saving us700063-II-SACV.sac
# Saving us700063-IU-FURI.sac
# Saving us700063-G-EDA.sac
# Saving us700063-IU-LSZ.sac
# Saving us700063-IU-TSUM.sac
# Saving us700063-II-ASCN.sac
# Saving us700063-G-CRZF.sac
# Saving us700063-II-WRAB.sac
# Saving us700063-G-TRIS.sac
# Saving us700063-IU-CASY.sac
# Saving us700063-II-HOPE.sac
# Saving us700063-G-SPB.sac
# Saving us700063-IU-TRQA.sac
# Saving us700063-G-PEL.sac
# Saving us700063-II-NNA.sac
# Saving us700063-IU-SDV.sac
# Saving us700063-CU-BBGH.sac
# Saving us700063-CU-ANWB.sac
# Saving us700063-IU-DWPF.sac
# Saving us700063-IU-BBSR.sac
# Saving us700063-IU-HRV.sac
# Saving us700063-G-IVI.sac
# Saving us700091-II-BORG.sac
# Saving us700091-II-CMLA.sac
# Saving us700091-II-ESK.sac
# Saving us700091-II-KIV.sac
# Saving us700091-II-SACV.sac
# Saving us700091-IU-FURI.sac
# Saving us700091-G-EDA.sac
# Saving us700091-IU-LSZ.sac
# Saving us700091-IU-TSUM.sac
# Saving us700091-II-ASCN.sac
# Saving us700091-G-CRZF.sac
# Saving us700091-II-WRAB.sac
# Saving us700091-G-TRIS.sac
# Saving us700091-IU-CASY.sac
# Saving us700091-II-HOPE.sac
# Saving us700091-G-SPB.sac
# Saving us700091-IU-TRQA.sac
# Saving us700091-G-PEL.sac
# Saving us700091-II-NNA.sac
# Saving us700091-IU-SDV.sac
# Saving us700091-CU-BBGH.sac
# Saving us700091-CU-ANWB.sac
# Saving us700091-IU-DWPF.sac
# Saving us700091-IU-BBSR.sac
# Saving us700091-IU-HRV.sac
# Saving us700091-G-IVI.sac
# Saving us700053-II-BORG.sac
# Saving us700053-II-CMLA.sac
# Saving us700053-II-ESK.sac
# Saving us700053-II-KIV.sac
# Saving us700053-II-SACV.sac
# Saving us700053-IU-FURI.sac
# Saving us700053-G-EDA.sac
# Saving us700053-IU-LSZ.sac
# Saving us700053-IU-TSUM.sac
# Saving us700053-II-ASCN.sac
# Saving us700053-G-CRZF.sac
# Saving us700053-II-WRAB.sac
# Saving us700053-G-TRIS.sac
# Saving us700053-IU-CASY.sac
# Saving us700053-II-HOPE.sac
# Saving us700053-G-SPB.sac
# Saving us700053-IU-TRQA.sac
# Saving us700053-G-PEL.sac
# Saving us700053-II-NNA.sac
# Saving us700053-IU-SDV.sac
# Saving us700053-CU-BBGH.sac
# Saving us700053-CU-ANWB.sac
# Saving us700053-IU-DWPF.sac
# Saving us700053-IU-BBSR.sac
# Saving us700053-IU-HRV.sac
# Saving us700053-G-IVI.sac
# Saving us700072-II-BORG.sac
# Saving us700072-II-CMLA.sac
# Saving us700072-II-ESK.sac
# Saving us700072-II-KIV.sac
# Saving us700072-II-SACV.sac
# Saving us700072-IU-FURI.sac
# Saving us700072-G-EDA.sac
# Saving us700072-IU-LSZ.sac
# Saving us700072-IU-TSUM.sac
# Saving us700072-II-ASCN.sac
# Saving us700072-G-CRZF.sac
# Saving us700072-II-WRAB.sac
# Saving us700072-G-TRIS.sac
# Saving us700072-IU-CASY.sac
# Saving us700072-II-HOPE.sac
# Saving us700072-G-SPB.sac
# Saving us700072-IU-TRQA.sac
# Saving us700072-G-PEL.sac
# Saving us700072-II-NNA.sac
# Saving us700072-IU-SDV.sac
# Saving us700072-CU-BBGH.sac
# Saving us700072-CU-ANWB.sac
# Saving us700072-IU-DWPF.sac
# Saving us700072-IU-BBSR.sac
# Saving us700072-IU-HRV.sac
# Saving us700072-G-IVI.sac

# %%
getWaveform()
# Out:
# Saving us7000bivi-II-BORG.sac
# Saving us7000bivi-II-CMLA.sac
# Saving us7000bivi-II-ESK.sac
# Saving us7000bivi-II-KIV.sac
# Saving us7000bivi-II-SACV.sac
# Saving us7000bivi-IU-FURI.sac
# Saving us7000bivi-G-EDA.sac
# Saving us7000bivi-IU-LSZ.sac
# Saving us7000bivi-IU-TSUM.sac
# Saving us7000bivi-II-ASCN.sac
# Saving us7000bivi-G-CRZF.sac
# Saving us7000bivi-II-WRAB.sac
# Saving us7000bivi-G-TRIS.sac
# Saving us7000bivi-IU-CASY.sac
# Saving us7000bivi-II-HOPE.sac
# Saving us7000bivi-G-SPB.sac
# Saving us7000bivi-IU-TRQA.sac
# Saving us7000bivi-G-PEL.sac
# Saving us7000bivi-II-NNA.sac
# Saving us7000bivi-IU-SDV.sac
# Saving us7000bivi-CU-BBGH.sac
# Saving us7000bivi-CU-ANWB.sac
# Saving us7000bivi-IU-DWPF.sac
# Saving us7000bivi-IU-BBSR.sac
# Saving us7000bivi-IU-HRV.sac
# Saving us7000bivi-G-IVI.sac
# Saving us7000blsw-II-BORG.sac
# Saving us7000blsw-II-CMLA.sac
# Saving us7000blsw-II-ESK.sac
# Saving us7000blsw-II-KIV.sac
# Saving us7000blsw-II-SACV.sac
# Saving us7000blsw-IU-FURI.sac
# Saving us7000blsw-G-EDA.sac
# Saving us7000blsw-IU-LSZ.sac
# Saving us7000blsw-IU-TSUM.sac
# Saving us7000blsw-II-ASCN.sac
# Saving us7000blsw-G-CRZF.sac
# Saving us7000blsw-II-WRAB.sac
# Saving us7000blsw-G-TRIS.sac
# Saving us7000blsw-IU-CASY.sac
# Saving us7000blsw-II-HOPE.sac
# Saving us7000blsw-G-SPB.sac
# Saving us7000blsw-IU-TRQA.sac
# Saving us7000blsw-G-PEL.sac
# Saving us7000blsw-II-NNA.sac
# Saving us7000blsw-IU-SDV.sac
# Saving us7000blsw-CU-BBGH.sac
# Saving us7000blsw-CU-ANWB.sac
# Saving us7000blsw-IU-DWPF.sac
# Saving us7000blsw-IU-BBSR.sac
# Saving us7000blsw-IU-HRV.sac
# Saving us7000blsw-G-IVI.sac
# Saving us7000bli6-II-BORG.sac
# Saving us7000bli6-II-CMLA.sac
# Saving us7000bli6-II-ESK.sac
# Saving us7000bli6-II-KIV.sac
# Saving us7000bli6-II-SACV.sac
# Saving us7000bli6-IU-FURI.sac
# Saving us7000bli6-G-EDA.sac
# Saving us7000bli6-IU-LSZ.sac
# Saving us7000bli6-IU-TSUM.sac
# Saving us7000bli6-II-ASCN.sac
# Saving us7000bli6-G-CRZF.sac
# Saving us7000bli6-II-WRAB.sac
# Saving us7000bli6-G-TRIS.sac
# Saving us7000bli6-IU-CASY.sac
# Saving us7000bli6-II-HOPE.sac
# Saving us7000bli6-G-SPB.sac
# Saving us7000bli6-IU-TRQA.sac
# Saving us7000bli6-G-PEL.sac
# Saving us7000bli6-II-NNA.sac
# Saving us7000bli6-IU-SDV.sac
# Saving us7000bli6-CU-BBGH.sac
# Saving us7000bli6-CU-ANWB.sac
# Saving us7000bli6-IU-DWPF.sac
# Saving us7000bli6-IU-BBSR.sac
# Saving us7000bli6-IU-HRV.sac
# Saving us7000bli6-G-IVI.sac
# Saving us7000bjem-II-BORG.sac
# Saving us7000bjem-II-CMLA.sac
# Saving us7000bjem-II-ESK.sac
# Saving us7000bjem-II-KIV.sac
# Saving us7000bjem-II-SACV.sac
# Saving us7000bjem-IU-FURI.sac
# Saving us7000bjem-G-EDA.sac
# Saving us7000bjem-IU-LSZ.sac
# Saving us7000bjem-IU-TSUM.sac
# Saving us7000bjem-II-ASCN.sac
# Saving us7000bjem-G-CRZF.sac
# Saving us7000bjem-II-WRAB.sac
# Saving us7000bjem-G-TRIS.sac
# Saving us7000bjem-IU-CASY.sac
# Saving us7000bjem-II-HOPE.sac
# Saving us7000bjem-G-SPB.sac
# Saving us7000bjem-IU-TRQA.sac
# Saving us7000bjem-G-PEL.sac
# Saving us7000bjem-II-NNA.sac
# Saving us7000bjem-IU-SDV.sac
# Saving us7000bjem-CU-BBGH.sac
# Saving us7000bjem-CU-ANWB.sac
# Saving us7000bjem-IU-DWPF.sac
# Saving us7000bjem-IU-BBSR.sac
# Saving us7000bjem-IU-HRV.sac
# Saving us7000bjem-G-IVI.sac
# Saving us7000blt2-II-BORG.sac
# Saving us7000blt2-II-CMLA.sac
# Saving us7000blt2-II-ESK.sac
# Saving us7000blt2-II-KIV.sac
# Saving us7000blt2-II-SACV.sac
# Saving us7000blt2-IU-FURI.sac
# Saving us7000blt2-G-EDA.sac
# Saving us7000blt2-IU-LSZ.sac
# Saving us7000blt2-IU-TSUM.sac
# Saving us7000blt2-II-ASCN.sac
# Saving us7000blt2-G-CRZF.sac
# Saving us7000blt2-II-WRAB.sac
# Saving us7000blt2-G-TRIS.sac
# Saving us7000blt2-IU-CASY.sac
# Saving us7000blt2-II-HOPE.sac
# Saving us7000blt2-G-SPB.sac
# Saving us7000blt2-IU-TRQA.sac
# Saving us7000blt2-G-PEL.sac
# Saving us7000blt2-II-NNA.sac
# Saving us7000blt2-IU-SDV.sac
# Saving us7000blt2-CU-BBGH.sac
# Saving us7000blt2-CU-ANWB.sac
# Saving us7000blt2-IU-DWPF.sac
# Saving us7000blt2-IU-BBSR.sac
# Saving us7000blt2-IU-HRV.sac
# Saving us7000blt2-G-IVI.sac
